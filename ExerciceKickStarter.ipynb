# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo
import datetime

# %%
client = pymongo.MongoClient('mongo')
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %%
len(df_ks)
# Out:
# 150000

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks = df_ks.rename(columns={"ID" : "_id"})
df_ks['launched'] = pd.to_datetime(df_ks['launched'], format='%Y-%m-%d', errors = "coerce")
df_ks['deadline'] = pd.to_datetime(df_ks['deadline'], format='%Y-%m-%d', errors = "coerce")
df_ks['backers'] = pd.to_numeric(df_ks['backers'], errors="coerce")
df_ks['goal'] = pd.to_numeric(df_ks['goal'], errors="coerce")
df_ks['pledged'] = pd.to_numeric(df_ks['pledged'], errors="coerce")
df_ks['usd pledged'] = pd.to_numeric(df_ks['usd pledged'], errors="coerce")

df_ks = df_ks.dropna()

df_ks['backers'] = df_ks['backers'].astype("int")
df_ks['goal'] = df_ks['goal'].astype("int")
df_ks['pledged'] = df_ks['pledged'].astype("int")
df_ks['usd pledged'] = df_ks['usd pledged'].astype("float")

# %%
len(df_ks)
# Out:
# 148515

# %% [markdown]
# ### Importer les données

# %%
collection.delete_many({})
collection.insert_many(df_ks.to_dict(orient='records'))
cursor = collection.find()

# %% [markdown]
# ## Question 1

# %%
most_donate = collection.aggregate([
    {"$sort":{"usd_pledged_real":-1}},
    {"$limit" : 5}
])
list(most_donate)
# Out:
# [{'_id': 342886736,
#   'name': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 8, 30, 0, 0),
#   'goal': 50000,
#   'launched': datetime.datetime(2014, 7, 8, 10, 14, 37),
#   'pledged': 13285226,
#   'state': 'successful',
#   'backers': 62642,
#   'country': 'US',
#   'usd pledged': 13285226.36,
#   'usd_pledged_real': 13285226.36},
#  {'_id': 2103598555,
#   'name': 'Pebble 2, Time 2 + All-New Pebble Core',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 6, 30, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2016, 5, 24, 15, 49, 52),
#   'pledged': 12779843,
#   'state': 'successful',
#   'backers': 66673,
#   'country': 'US',
#   'usd pledged': 12779843.49,
#   'usd_pledged_real': 12779843.49},
#  {'_id': 1033978702,
#   'name': 'OUYA: A New Kind of Video Game Console',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 8, 9, 0, 0),
#   'goal': 950000,
#   'launched': datetime.datetime(2012, 7, 10, 14, 44, 41),
#   'pledged': 8596474,
#   'state': 'successful',
#   'backers': 63416,
#   'country': 'US',
#   'usd pledged': 8596474.58,
#   'usd_pledged_real': 8596474.58},
#  {'_id': 450099426,
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 9, 10, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2016, 7, 13, 0, 47, 35),
#   'pledged': 6565782,
#   'state': 'successful',
#   'backers': 26359,
#   'country': 'US',
#   'usd pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5},
#  {'_id': 1386523707,
#   'name': 'Fidget Cube: A Vinyl Desk Toy',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 10, 20, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2016, 8, 30, 22, 2, 9),
#   'pledged': 6465690,
#   'state': 'successful',
#   'backers': 154926,
#   'country': 'US',
#   'usd pledged': 13770.0,
#   'usd_pledged_real': 6465690.3}]

# %% [markdown]
# ## Question 2

# %%
number_state_ok = collection.find({"state":"successful"})
len(list(number_state_ok))
# Out:
# 52998

# %% [markdown]
# ## Question 3

# %%
number_project = collection.aggregate([{"$group" : {"_id" : "$category", "numberprojectbycategory" : {"$sum" : 1}}}])
list(number_project)
# Out:
# [{'_id': 'Gaming Hardware', 'numberprojectbycategory': 178},
#  {'_id': 'Periodicals', 'numberprojectbycategory': 517},
#  {'_id': 'Performance Art', 'numberprojectbycategory': 855},
#  {'_id': 'Translations', 'numberprojectbycategory': 76},
#  {'_id': 'Academic', 'numberprojectbycategory': 367},
#  {'_id': 'Wearables', 'numberprojectbycategory': 508},
#  {'_id': 'Comics', 'numberprojectbycategory': 1931},
#  {'_id': "Farmer's Markets", 'numberprojectbycategory': 175},
#  {'_id': 'Animals', 'numberprojectbycategory': 97},
#  {'_id': 'Video Games', 'numberprojectbycategory': 4797},
#  {'_id': 'Thrillers', 'numberprojectbycategory': 302},
#  {'_id': 'Action', 'numberprojectbycategory': 282},
#  {'_id': 'Food', 'numberprojectbycategory': 4612},
#  {'_id': 'Interactive Design', 'numberprojectbycategory': 146},
#  {'_id': 'Calendars', 'numberprojectbycategory': 112},
#  {'_id': 'Country & Folk', 'numberprojectbycategory': 1790},
#  {'_id': 'Letterpress', 'numberprojectbycategory': 24},
#  {'_id': 'Indie Rock', 'numberprojectbycategory': 2192},
#  {'_id': 'Kids', 'numberprojectbycategory': 109},
#  {'_id': 'Technology', 'numberprojectbycategory': 2689},
#  {'_id': 'Festivals', 'numberprojectbycategory': 313},
#  {'_id': 'Fabrication Tools', 'numberprojectbycategory': 96},
#  {'_id': 'Sound', 'numberprojectbycategory': 255},
#  {'_id': 'Civic Design', 'numberprojectbycategory': 130},
#  {'_id': 'Documentary', 'numberprojectbycategory': 6497},
#  {'_id': 'Woodworking', 'numberprojectbycategory': 433},
#  {'_id': 'Comic Books', 'numberprojectbycategory': 1032},
#  {'_id': 'Television', 'numberprojectbycategory': 401},
#  {'_id': 'Ceramics', 'numberprojectbycategory': 128},
#  {'_id': 'Quilts', 'numberprojectbycategory': 32},
#  {'_id': 'Robots', 'numberprojectbycategory': 237},
#  {'_id': 'Mobile Games', 'numberprojectbycategory': 650},
#  {'_id': 'Games', 'numberprojectbycategory': 1331},
#  {'_id': 'Graphic Novels', 'numberprojectbycategory': 702},
#  {'_id': 'Fiction', 'numberprojectbycategory': 3703},
#  {'_id': 'Comedy', 'numberprojectbycategory': 923},
#  {'_id': 'Dance', 'numberprojectbycategory': 900},
#  {'_id': 'Print', 'numberprojectbycategory': 287},
#  {'_id': 'Immersive', 'numberprojectbycategory': 131},
#  {'_id': 'Fantasy', 'numberprojectbycategory': 132},
#  {'_id': 'Vegan', 'numberprojectbycategory': 229},
#  {'_id': 'Animation', 'numberprojectbycategory': 1017},
#  {'_id': 'Drinks', 'numberprojectbycategory': 995},
#  {'_id': 'Photography', 'numberprojectbycategory': 2239},
#  {'_id': 'Nature', 'numberprojectbycategory': 219},
#  {'_id': 'Knitting', 'numberprojectbycategory': 78},
#  {'_id': 'Nonfiction', 'numberprojectbycategory': 3390},
#  {'_id': 'Young Adult', 'numberprojectbycategory': 328},
#  {'_id': 'Stationery', 'numberprojectbycategory': 90},
#  {'_id': 'Residencies', 'numberprojectbycategory': 32},
#  {'_id': 'Playing Cards', 'numberprojectbycategory': 963},
#  {'_id': 'Pottery', 'numberprojectbycategory': 40},
#  {'_id': 'Hardware', 'numberprojectbycategory': 1430},
#  {'_id': 'Restaurants', 'numberprojectbycategory': 1088},
#  {'_id': 'Chiptune', 'numberprojectbycategory': 10},
#  {'_id': 'Typography', 'numberprojectbycategory': 44},
#  {'_id': "Children's Books", 'numberprojectbycategory': 2686},
#  {'_id': 'Live Games', 'numberprojectbycategory': 394},
#  {'_id': 'Journalism', 'numberprojectbycategory': 672},
#  {'_id': 'DIY', 'numberprojectbycategory': 480},
#  {'_id': 'Theater', 'numberprojectbycategory': 2786},
#  {'_id': 'Cookbooks', 'numberprojectbycategory': 217},
#  {'_id': 'Makerspaces', 'numberprojectbycategory': 91},
#  {'_id': 'Childrenswear', 'numberprojectbycategory': 192},
#  {'_id': 'Sculpture', 'numberprojectbycategory': 737},
#  {'_id': 'Zines', 'numberprojectbycategory': 144},
#  {'_id': 'Accessories', 'numberprojectbycategory': 1203},
#  {'_id': 'Product Design', 'numberprojectbycategory': 8885},
#  {'_id': 'Classical Music', 'numberprojectbycategory': 1064},
#  {'_id': 'Fashion', 'numberprojectbycategory': 3379},
#  {'_id': 'Publishing', 'numberprojectbycategory': 2147},
#  {'_id': 'Art', 'numberprojectbycategory': 3358},
#  {'_id': 'Family', 'numberprojectbycategory': 130},
#  {'_id': 'Flight', 'numberprojectbycategory': 158},
#  {'_id': 'Rock', 'numberprojectbycategory': 2707},
#  {'_id': 'Fine Art', 'numberprojectbycategory': 290},
#  {'_id': 'Movie Theaters', 'numberprojectbycategory': 90},
#  {'_id': 'Video Art', 'numberprojectbycategory': 65},
#  {'_id': 'Puzzles', 'numberprojectbycategory': 95},
#  {'_id': 'Metal', 'numberprojectbycategory': 274},
#  {'_id': 'Webseries', 'numberprojectbycategory': 2316},
#  {'_id': 'Camera Equipment', 'numberprojectbycategory': 165},
#  {'_id': 'Digital Art', 'numberprojectbycategory': 524},
#  {'_id': 'Pet Fashion', 'numberprojectbycategory': 51},
#  {'_id': 'Blues', 'numberprojectbycategory': 113},
#  {'_id': 'Workshops', 'numberprojectbycategory': 59},
#  {'_id': 'Bacon', 'numberprojectbycategory': 78},
#  {'_id': 'Places', 'numberprojectbycategory': 283},
#  {'_id': 'Gadgets', 'numberprojectbycategory': 1210},
#  {'_id': 'Web', 'numberprojectbycategory': 2017},
#  {'_id': 'Farms', 'numberprojectbycategory': 482},
#  {'_id': 'Candles', 'numberprojectbycategory': 168},
#  {'_id': 'Space Exploration', 'numberprojectbycategory': 137},
#  {'_id': 'Crafts', 'numberprojectbycategory': 1834},
#  {'_id': 'Plays', 'numberprojectbycategory': 539},
#  {'_id': 'World Music', 'numberprojectbycategory': 850},
#  {'_id': 'Couture', 'numberprojectbycategory': 108},
#  {'_id': 'Illustration', 'numberprojectbycategory': 1263},
#  {'_id': 'Hip-Hop', 'numberprojectbycategory': 1555},
#  {'_id': 'Printing', 'numberprojectbycategory': 83},
#  {'_id': 'Horror', 'numberprojectbycategory': 525},
#  {'_id': 'Installations', 'numberprojectbycategory': 178},
#  {'_id': 'Photo', 'numberprojectbycategory': 58},
#  {'_id': 'Jazz', 'numberprojectbycategory': 733},
#  {'_id': 'Faith', 'numberprojectbycategory': 439},
#  {'_id': 'Software', 'numberprojectbycategory': 1193},
#  {'_id': 'Art Books', 'numberprojectbycategory': 1065},
#  {'_id': 'Webcomics', 'numberprojectbycategory': 259},
#  {'_id': 'Music Videos', 'numberprojectbycategory': 299},
#  {'_id': 'Anthologies', 'numberprojectbycategory': 300},
#  {'_id': 'Apps', 'numberprojectbycategory': 2535},
#  {'_id': 'Glass', 'numberprojectbycategory': 51},
#  {'_id': 'Experimental', 'numberprojectbycategory': 357},
#  {'_id': 'DIY Electronics', 'numberprojectbycategory': 358},
#  {'_id': 'Taxidermy', 'numberprojectbycategory': 7},
#  {'_id': 'Pop', 'numberprojectbycategory': 1302},
#  {'_id': 'Spaces', 'numberprojectbycategory': 331},
#  {'_id': 'Drama', 'numberprojectbycategory': 871},
#  {'_id': 'Music', 'numberprojectbycategory': 5293},
#  {'_id': 'Ready-to-wear', 'numberprojectbycategory': 332},
#  {'_id': 'Science Fiction', 'numberprojectbycategory': 274},
#  {'_id': 'Film & Video', 'numberprojectbycategory': 3657},
#  {'_id': 'Electronic Music', 'numberprojectbycategory': 858},
#  {'_id': 'Musical', 'numberprojectbycategory': 367},
#  {'_id': 'People', 'numberprojectbycategory': 440},
#  {'_id': 'Painting', 'numberprojectbycategory': 1288},
#  {'_id': 'Apparel', 'numberprojectbycategory': 2827},
#  {'_id': 'R&B', 'numberprojectbycategory': 172},
#  {'_id': 'Literary Spaces', 'numberprojectbycategory': 10},
#  {'_id': 'Crochet', 'numberprojectbycategory': 61},
#  {'_id': 'Mixed Media', 'numberprojectbycategory': 1118},
#  {'_id': 'Small Batch', 'numberprojectbycategory': 701},
#  {'_id': 'Footwear', 'numberprojectbycategory': 379},
#  {'_id': 'Embroidery', 'numberprojectbycategory': 49},
#  {'_id': 'Radio & Podcasts', 'numberprojectbycategory': 349},
#  {'_id': 'Romance', 'numberprojectbycategory': 74},
#  {'_id': 'Narrative Film', 'numberprojectbycategory': 2097},
#  {'_id': 'Conceptual Art', 'numberprojectbycategory': 393},
#  {'_id': 'Video', 'numberprojectbycategory': 147},
#  {'_id': 'Textiles', 'numberprojectbycategory': 105},
#  {'_id': 'Jewelry', 'numberprojectbycategory': 472},
#  {'_id': 'Tabletop Games', 'numberprojectbycategory': 5579},
#  {'_id': '3D Printing', 'numberprojectbycategory': 271},
#  {'_id': 'Food Trucks', 'numberprojectbycategory': 687},
#  {'_id': 'Events', 'numberprojectbycategory': 321},
#  {'_id': 'Design', 'numberprojectbycategory': 1641},
#  {'_id': 'Latin', 'numberprojectbycategory': 63},
#  {'_id': 'Literary Journals', 'numberprojectbycategory': 118},
#  {'_id': 'Graphic Design', 'numberprojectbycategory': 765},
#  {'_id': 'Punk', 'numberprojectbycategory': 127},
#  {'_id': 'Shorts', 'numberprojectbycategory': 4857},
#  {'_id': 'Photobooks', 'numberprojectbycategory': 608},
#  {'_id': 'Community Gardens', 'numberprojectbycategory': 115},
#  {'_id': 'Weaving', 'numberprojectbycategory': 38},
#  {'_id': 'Poetry', 'numberprojectbycategory': 532},
#  {'_id': 'Public Art', 'numberprojectbycategory': 1248},
#  {'_id': 'Performances', 'numberprojectbycategory': 414},
#  {'_id': 'Audio', 'numberprojectbycategory': 164},
#  {'_id': 'Architecture', 'numberprojectbycategory': 300}]

# %% [markdown]
# ## Question 4

# %%
number_french_project_b2016 = collection.find({"$and" : [ {"country":"FR"}, {"launched": {"$lt" : datetime.datetime(2016, 1, 1, 0, 0, 0, 0)}}]})
list(number_french_project_b2016)
# Out:
# [{'_id': 545482362,
#   'name': 'Depeche Mode Bar Belgium',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 1, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 5, 27, 11, 29, 28),
#   'pledged': 305,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'FR',
#   'usd pledged': 333.98121895,
#   'usd_pledged_real': 338.42637284599937},
#  {'_id': 400288569,
#   'name': 'Dracucat : A vampire kitten card game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 29, 0, 0),
#   'goal': 1900,
#   'launched': datetime.datetime(2015, 9, 29, 7, 4, 8),
#   'pledged': 2944,
#   'state': 'successful',
#   'backers': 129,
#   'country': 'FR',
#   'usd pledged': 3295.37237632,
#   'usd_pledged_real': 3243.3980764357875},
#  {'_id': 1990332786,
#   'name': 'Minotaur enjoy your life & your ice cream',
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 31, 0, 0),
#   'goal': 3800,
#   'launched': datetime.datetime(2015, 7, 11, 9, 19, 13),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 42552254,
#   'name': 'Catch Me',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 14, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 9, 19, 14, 48, 6),
#   'pledged': 226,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 257.54692190000003,
#   'usd_pledged_real': 256.73649293406646},
#  {'_id': 663285707,
#   'name': 'Co-park',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 12, 0, 0),
#   'goal': 2500,
#   'launched': datetime.datetime(2015, 10, 13, 11, 17, 28),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1859319535,
#   'name': 'Projet Coworking & Gaming',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 8, 0, 0),
#   'goal': 690000,
#   'launched': datetime.datetime(2015, 6, 9, 15, 33, 22),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1946351705,
#   'name': 'Banlieues - dix ans apr?s',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 8, 0, 0),
#   'goal': 40000,
#   'launched': datetime.datetime(2015, 9, 9, 11, 18, 16),
#   'pledged': 12579,
#   'state': 'failed',
#   'backers': 235,
#   'country': 'FR',
#   'usd pledged': 14042.99647443,
#   'usd_pledged_real': 13540.074487093929},
#  {'_id': 1452688704,
#   'name': 'Jungle House',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 25, 0, 0),
#   'goal': 12000,
#   'launched': datetime.datetime(2015, 11, 4, 15, 41, 26),
#   'pledged': 1350,
#   'state': 'failed',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 1486.859463,
#   'usd_pledged_real': 1428.2993715482764},
#  {'_id': 415130131,
#   'name': 'Holystream',
#   'category': 'Faith',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 1, 16, 0, 0),
#   'goal': 25000,
#   'launched': datetime.datetime(2015, 11, 27, 1, 58, 35),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1787211494,
#   'name': 'FURCY&FAIR',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 27, 0, 0),
#   'goal': 9000,
#   'launched': datetime.datetime(2015, 6, 26, 13, 48, 57),
#   'pledged': 9392,
#   'state': 'successful',
#   'backers': 71,
#   'country': 'FR',
#   'usd pledged': 10525.65516128,
#   'usd_pledged_real': 10300.165601044057},
#  {'_id': 537199454,
#   'name': 'www.worldoo.info Moteur de Recherche',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 11, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2015, 6, 12, 1, 10, 53),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 598062270,
#   'name': "Tonight I'll Dream About You",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 21, 0, 0),
#   'goal': 5900,
#   'launched': datetime.datetime(2015, 6, 22, 19, 17, 34),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1046340865,
#   'name': 'Tikiwi, a "Kiwi style" Food Truck in France!',
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 14, 0, 0),
#   'goal': 10000,
#   'launched': datetime.datetime(2015, 10, 25, 19, 27, 21),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 630729432,
#   'name': 'Folky-Dolls... Cute LED table lamps for kids of the world!',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 20, 0, 0),
#   'goal': 130000,
#   'launched': datetime.datetime(2015, 6, 9, 6, 13, 23),
#   'pledged': 1266,
#   'state': 'failed',
#   'backers': 16,
#   'country': 'FR',
#   'usd pledged': 1405.16937972,
#   'usd_pledged_real': 1384.8779207140985},
#  {'_id': 912757617,
#   'name': 'Siesta, Nap.',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 31, 0, 0),
#   'goal': 10000,
#   'launched': datetime.datetime(2015, 12, 1, 18, 45, 21),
#   'pledged': 5,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.2934756,
#   'usd_pledged_real': 5.443480343592482},
#  {'_id': 1515614634,
#   'name': 'Chronologia Trigalight Dive Watch',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 7, 0, 0),
#   'goal': 35500,
#   'launched': datetime.datetime(2015, 7, 8, 8, 20, 48),
#   'pledged': 12445,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'FR',
#   'usd pledged': 13734.97515005,
#   'usd_pledged_real': 13616.122714690533},
#  {'_id': 629586349,
#   'name': 'HUMANIMAGES',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 16, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 6, 16, 23, 30, 42),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 137985493,
#   'name': "Grandpa, How Do You Make a  Kachina? - A children's book",
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 18, 0, 0),
#   'goal': 7000,
#   'launched': datetime.datetime(2015, 11, 13, 18, 5, 8),
#   'pledged': 7000,
#   'state': 'successful',
#   'backers': 84,
#   'country': 'FR',
#   'usd pledged': 7534.124220000002,
#   'usd_pledged_real': 7585.198027848513},
#  {'_id': 601724985,
#   'name': 'Shampoing MARLIVEIRA',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 25, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2015, 9, 25, 20, 41, 48),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 338426049,
#   'name': 'Asterion- By director of FMA Brotherhood (Canceled)',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 28, 0, 0),
#   'goal': 135000,
#   'launched': datetime.datetime(2015, 6, 13, 11, 55, 3),
#   'pledged': 33785,
#   'state': 'canceled',
#   'backers': 155,
#   'country': 'FR',
#   'usd pledged': 38021.59406595,
#   'usd_pledged_real': 37051.8627375717},
#  {'_id': 1640048861,
#   'name': 'ARBITRELEC',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 30, 0, 0),
#   'goal': 25000,
#   'launched': datetime.datetime(2015, 10, 31, 17, 1, 23),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 378181109,
#   'name': 'tiny & Tall: Gleipnir',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 8, 0, 0),
#   'goal': 8000,
#   'launched': datetime.datetime(2015, 9, 8, 9, 3, 3),
#   'pledged': 6817,
#   'state': 'failed',
#   'backers': 268,
#   'country': 'FR',
#   'usd pledged': 7603.20147418,
#   'usd_pledged_real': 7745.446695374547},
#  {'_id': 1730882800,
#   'name': '100 MECA',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 6, 0, 0),
#   'goal': 8000,
#   'launched': datetime.datetime(2015, 7, 12, 1, 47, 15),
#   'pledged': 320,
#   'state': 'failed',
#   'backers': 13,
#   'country': 'FR',
#   'usd pledged': 354.7722976,
#   'usd_pledged_real': 350.11323975098196},
#  {'_id': 1330309415,
#   'name': 'Today is a good day',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 11, 0, 0),
#   'goal': 25000,
#   'launched': datetime.datetime(2015, 5, 27, 11, 6, 11),
#   'pledged': 285,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 312.08081115,
#   'usd_pledged_real': 310.3358160198615},
#  {'_id': 327985277,
#   'name': 'TOP SCHOOL',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 27, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 5, 28, 21, 40, 45),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1647853204,
#   'name': 'Omega Project',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 29, 0, 0),
#   'goal': 100000,
#   'launched': datetime.datetime(2015, 7, 30, 23, 58, 32),
#   'pledged': 11,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 12.18702881,
#   'usd_pledged_real': 12.25176258311707},
#  {'_id': 35689425,
#   'name': 'Eyes of India - Exhibition - Exposition - Prints - Photos',
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 2, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2015, 9, 2, 0, 13, 32),
#   'pledged': 388,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'FR',
#   'usd pledged': 436.11381972,
#   'usd_pledged_real': 433.00671830011385},
#  {'_id': 1933641835,
#   'name': 'Body scores',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 15, 0, 0),
#   'goal': 6000,
#   'launched': datetime.datetime(2015, 7, 31, 9, 46, 36),
#   'pledged': 50,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 54.866071999999996,
#   'usd_pledged_real': 57.09522341360922},
#  {'_id': 1523608703,
#   'name': 'Marcheese',
#   'category': 'Webcomics',
#   'main_category': 'Comics',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 24, 0, 0),
#   'goal': 100,
#   'launched': datetime.datetime(2015, 11, 14, 15, 50, 26),
#   'pledged': 126,
#   'state': 'successful',
#   'backers': 5,
#   'country': 'FR',
#   'usd pledged': 135.97146738,
#   'usd_pledged_real': 137.9325444175634},
#  {'_id': 1896558868,
#   'name': 'Mots ?crits',
#   'category': 'Spaces',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 16, 0, 0),
#   'goal': 2500,
#   'launched': datetime.datetime(2015, 6, 16, 11, 12, 17),
#   'pledged': 300,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'FR',
#   'usd pledged': 336.223737,
#   'usd_pledged_real': 326.66928002090685},
#  {'_id': 1040232257,
#   'name': "Lucifer's rise",
#   'category': 'Fantasy',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 29, 0, 0),
#   'goal': 5000,
#   'launched': datetime.datetime(2015, 9, 30, 17, 40, 25),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1673013190,
#   'name': 'LA BOX DEVINS',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 9, 0, 0),
#   'goal': 40000,
#   'launched': datetime.datetime(2015, 10, 10, 20, 26, 55),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1115987670,
#   'name': 'TTLamp: the New Flexible, Modular & Connected Lamp',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 23, 0, 0),
#   'goal': 25000,
#   'launched': datetime.datetime(2015, 11, 24, 17, 45, 50),
#   'pledged': 398,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 422.36407148,
#   'usd_pledged_real': 435.69168792214475},
#  {'_id': 1546762014,
#   'name': 'Montaign Addict :  Accessoires de ski - Ski Accesories',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 2, 7, 0, 0),
#   'goal': 8000,
#   'launched': datetime.datetime(2015, 12, 29, 17, 27, 25),
#   'pledged': 8410,
#   'state': 'successful',
#   'backers': 43,
#   'country': 'FR',
#   'usd pledged': 9230.813140600001,
#   'usd_pledged_real': 9482.25319081766},
#  {'_id': 391218466,
#   'name': 'WHOUHAOU! Immersive installation dedicated to dance',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 26, 0, 0),
#   'goal': 27000,
#   'launched': datetime.datetime(2015, 5, 27, 19, 23, 5),
#   'pledged': 9200,
#   'state': 'failed',
#   'backers': 126,
#   'country': 'FR',
#   'usd pledged': 10074.187587999999,
#   'usd_pledged_real': 10305.813823232891},
#  {'_id': 1819520246,
#   'name': 'PINGA! Even Ha?ti needs Heroes...',
#   'category': 'Events',
#   'main_category': 'Comics',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 13, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2015, 7, 14, 12, 44, 43),
#   'pledged': 518,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 576.46636992,
#   'usd_pledged_real': 578.6545722647959},
#  {'_id': 1063655388,
#   'name': "Passions Automobiles  - Photos, tirages d'art - Art Pictures",
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 8, 0, 0),
#   'goal': 6500,
#   'launched': datetime.datetime(2015, 9, 18, 12, 12),
#   'pledged': 60,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 67.8518886,
#   'usd_pledged_real': 68.17174735550431},
#  {'_id': 26116111,
#   'name': "Faites revivre l'aviation fran?aise avec le HM 1000 Balerit",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 19, 0, 0),
#   'goal': 8000,
#   'launched': datetime.datetime(2015, 8, 20, 19, 44, 16),
#   'pledged': 175,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 193.30907575,
#   'usd_pledged_real': 193.97029483484815},
#  {'_id': 2123383062,
#   'name': 'Ulo',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 4, 0, 0),
#   'goal': 199000,
#   'launched': datetime.datetime(2015, 10, 5, 15, 48, 3),
#   'pledged': 1618869,
#   'state': 'successful',
#   'backers': 8330,
#   'country': 'FR',
#   'usd pledged': 1815079.1817613998,
#   'usd_pledged_real': 1764896.6705187191},
#  {'_id': 456970508,
#   'name': 'oracle des reflets - oracle/tarot deck',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 6, 0, 0),
#   'goal': 3700,
#   'launched': datetime.datetime(2015, 9, 6, 21, 48, 52),
#   'pledged': 8591,
#   'state': 'successful',
#   'backers': 178,
#   'country': 'FR',
#   'usd pledged': 9577.76878916,
#   'usd_pledged_real': 9761.058025518958},
#  {'_id': 1302550415,
#   'name': "STARCAP 'The French Cap'",
#   'category': 'Ready-to-wear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 29, 0, 0),
#   'goal': 7000,
#   'launched': datetime.datetime(2015, 5, 30, 9, 32, 56),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1917789498,
#   'name': "Let's Coffee App - Give or Take Free Coffee, meet people !",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 4, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2015, 11, 5, 19, 44, 15),
#   'pledged': 10,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 10.949640400000002,
#   'usd_pledged_real': 10.902034319604036},
#  {'_id': 1995297582,
#   'name': "Kat's Laser Crafts (Canceled)",
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 22, 0, 0),
#   'goal': 1300,
#   'launched': datetime.datetime(2015, 10, 14, 8, 54, 20),
#   'pledged': 30,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 34.072866,
#   'usd_pledged_real': 31.739986034406144},
#  {'_id': 1871137783,
#   'name': 'Pulssy Maxxi Wireless Speaker',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 26, 0, 0),
#   'goal': 50000,
#   'launched': datetime.datetime(2015, 5, 27, 7, 41, 33),
#   'pledged': 151,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 165.34807889,
#   'usd_pledged_real': 169.14977035958327},
#  {'_id': 1668097693,
#   'name': 'Formation Cr?ation Couture Comme une Pro',
#   'category': 'Couture',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 26, 0, 0),
#   'goal': 8000,
#   'launched': datetime.datetime(2015, 5, 27, 3, 49, 36),
#   'pledged': 10,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 10.985968699999999,
#   'usd_pledged_real': 11.201971546992269},
#  {'_id': 1750798706,
#   'name': 'French Riviera Candle',
#   'category': 'Candles',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 28, 0, 0),
#   'goal': 3925,
#   'launched': datetime.datetime(2015, 7, 2, 16, 7, 56),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1629922940,
#   'name': 'Made In France',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 22, 0, 0),
#   'goal': 600,
#   'launched': datetime.datetime(2015, 6, 2, 23, 51, 19),
#   'pledged': 600,
#   'state': 'successful',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 656.951088,
#   'usd_pledged_real': 672.1182928195362},
#  {'_id': 2003155960,
#   'name': 'Candle Lithophany personnalized',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 22, 0, 0),
#   'goal': 5000,
#   'launched': datetime.datetime(2015, 8, 23, 19, 59, 28),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1455581875,
#   'name': 'monkeywi - cache-webcam ultrafin prot?ge votre vie priv?e',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 13, 0, 0),
#   'goal': 1200,
#   'launched': datetime.datetime(2015, 10, 9, 0, 8, 49),
#   'pledged': 3893,
#   'state': 'successful',
#   'backers': 318,
#   'country': 'FR',
#   'usd pledged': 4388.11543835,
#   'usd_pledged_real': 4190.437234935739},
#  {'_id': 1162987071,
#   'name': 'PoDDI : Intelligent Showerhead - Water savings',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 10, 0, 0),
#   'goal': 1000,
#   'launched': datetime.datetime(2015, 9, 10, 20, 6, 30),
#   'pledged': 15,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 16.771469699999994,
#   'usd_pledged_real': 17.040032716862818},
#  {'_id': 494291320,
#   'name': 'ClanSMG Serveur',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 27, 0, 0),
#   'goal': 500,
#   'launched': datetime.datetime(2015, 5, 28, 19, 59, 1),
#   'pledged': 5,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.4380277,
#   'usd_pledged_real': 5.547973325344252},
#  {'_id': 2048324945,
#   'name': 'R?ve de fer short film (Canceled)',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 7, 0, 0),
#   'goal': 4500,
#   'launched': datetime.datetime(2015, 6, 7, 12, 6, 38),
#   'pledged': 565,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 627.9145241,
#   'usd_pledged_real': 631.9557071752139},
#  {'_id': 1521723928,
#   'name': 'myGOURMET, the finest food around me',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 25, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 9, 25, 23, 26, 55),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1177360909,
#   'name': 'La V?tith?que, biblioth?que de v?tements ? Bordeaux.',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 23, 0, 0),
#   'goal': 10000,
#   'launched': datetime.datetime(2015, 6, 24, 13, 45, 54),
#   'pledged': 10236,
#   'state': 'successful',
#   'backers': 66,
#   'country': 'FR',
#   'usd pledged': 11550.25756632,
#   'usd_pledged_real': 11533.911005442438},
#  {'_id': 1183070862,
#   'name': 'REWIND - a Short Film',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 3, 0, 0),
#   'goal': 1000,
#   'launched': datetime.datetime(2015, 7, 4, 16, 55, 12),
#   'pledged': 1098,
#   'state': 'successful',
#   'backers': 28,
#   'country': 'FR',
#   'usd pledged': 1217.87547858,
#   'usd_pledged_real': 1201.326053895557},
#  {'_id': 1179548226,
#   'name': "Construction d'un Bikepark",
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 11, 0, 0),
#   'goal': 1000,
#   'launched': datetime.datetime(2015, 7, 12, 10, 36, 42),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1779919492,
#   'name': 'New light',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 12, 0, 0),
#   'goal': 5000,
#   'launched': datetime.datetime(2015, 11, 12, 6, 35, 54),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 86530705,
#   'name': 'Nouveau jeu mobile/PC  ~~ New mobile/PC game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 30, 0, 0),
#   'goal': 3200,
#   'launched': datetime.datetime(2015, 10, 31, 15, 9, 19),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.09808779,
#   'usd_pledged_real': 1.088696068718496},
#  {'_id': 1302039296,
#   'name': 'SephiGame',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 30, 0, 0),
#   'goal': 50000,
#   'launched': datetime.datetime(2015, 10, 31, 18, 12, 56),
#   'pledged': 6,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 6.58852674,
#   'usd_pledged_real': 6.532176412310975},
#  {'_id': 671090174,
#   'name': 'Warn Da Nation Riddim',
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 26, 0, 0),
#   'goal': 7000,
#   'launched': datetime.datetime(2015, 5, 27, 21, 35, 2),
#   'pledged': 32,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 35.04065248,
#   'usd_pledged_real': 35.846308950375274},
#  {'_id': 233068935,
#   'name': 'Give life to my creatures and adopt them !',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 26, 0, 0),
#   'goal': 1000,
#   'launched': datetime.datetime(2015, 5, 27, 7, 45, 57),
#   'pledged': 1538,
#   'state': 'successful',
#   'backers': 52,
#   'country': 'FR',
#   'usd pledged': 1684.14135982,
#   'usd_pledged_real': 1686.7179189103229},
#  {'_id': 375710096,
#   'name': 'Logiciel gratuit de facturation en ligne (Control ERP)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 9, 0, 0),
#   'goal': 10000,
#   'launched': datetime.datetime(2015, 6, 10, 20, 34, 42),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1514912516,
#   'name': 'Tohu Bohu',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 10, 0, 0),
#   'goal': 1000,
#   'launched': datetime.datetime(2015, 11, 19, 15, 24, 11),
#   'pledged': 2025,
#   'state': 'successful',
#   'backers': 106,
#   'country': 'FR',
#   'usd pledged': 2153.251998,
#   'usd_pledged_real': 2217.379878235732},
#  {'_id': 163312974,
#   'name': '1 Apps for 1 life',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 23, 0, 0),
#   'goal': 150000,
#   'launched': datetime.datetime(2015, 11, 3, 20, 54, 52),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 2044197681,
#   'name': 'Welcome to Another World!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 27, 0, 0),
#   'goal': 35000,
#   'launched': datetime.datetime(2015, 10, 21, 12, 26, 50),
#   'pledged': 10331,
#   'state': 'failed',
#   'backers': 206,
#   'country': 'FR',
#   'usd pledged': 11710.93450151,
#   'usd_pledged_real': 10930.193190714996},
#  {'_id': 1524766221,
#   'name': 'ï¿½9 Universal Remote Control App for kid mum dad grandparents',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 26, 0, 0),
#   'goal': 19000,
#   'launched': datetime.datetime(2015, 5, 27, 9, 28, 38),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 204343701,
#   'name': 'ALTER WORLD',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 2, 0, 0),
#   'goal': 300,
#   'launched': datetime.datetime(2015, 7, 3, 9, 19, 40),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 45738099,
#   'name': 'FILM COMIQUE : Un Camping Car - Mon r?ve',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 10, 0, 0),
#   'goal': 50000,
#   'launched': datetime.datetime(2015, 9, 11, 2, 32, 30),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 550753770,
#   'name': 'MaTeHyS, a powerfull all-road individual electric vehicle.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 5, 0, 0),
#   'goal': 100000,
#   'launched': datetime.datetime(2015, 11, 5, 11, 44, 31),
#   'pledged': 924,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'FR',
#   'usd pledged': 1011.74677296,
#   'usd_pledged_real': 1011.7822259208972},
#  {'_id': 1114966662,
#   'name': 'Xculpter, the first hair and beard sculptor.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 10, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2015, 11, 12, 15, 37, 14),
#   'pledged': 1039,
#   'state': 'failed',
#   'backers': 16,
#   'country': 'FR',
#   'usd pledged': 1118.46467332,
#   'usd_pledged_real': 1137.7075029565065},
#  {'_id': 1871233881,
#   'name': 'Drops of Breath (Canceled)',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 27, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 6, 27, 13, 45, 7),
#   'pledged': 766,
#   'state': 'canceled',
#   'backers': 24,
#   'country': 'FR',
#   'usd pledged': 856.73606274,
#   'usd_pledged_real': 840.068872487196},
#  {'_id': 998418451,
#   'name': 'Miami en vid?o',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 25, 0, 0),
#   'goal': 400,
#   'launched': datetime.datetime(2015, 9, 25, 4, 11, 49),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1073912995,
#   'name': 'MIKS - When language learning becomes a game',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 31, 0, 0),
#   'goal': 4000,
#   'launched': datetime.datetime(2015, 6, 16, 0, 26, 47),
#   'pledged': 11,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 12.39285806,
#   'usd_pledged_real': 12.063652215873573},
#  {'_id': 776737905,
#   'name': 'Charlie Fly - A Mobile Action Game - iOS & Android',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 1, 0, 0),
#   'goal': 5600,
#   'launched': datetime.datetime(2015, 7, 3, 14, 26, 21),
#   'pledged': 2,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 2.21247504,
#   'usd_pledged_real': 2.188207748443637},
#  {'_id': 1483086435,
#   'name': 'Le Tribunal des Songes',
#   'category': 'Fantasy',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 30, 0, 0),
#   'goal': 350,
#   'launched': datetime.datetime(2015, 11, 30, 20, 49, 34),
#   'pledged': 353,
#   'state': 'successful',
#   'backers': 12,
#   'country': 'FR',
#   'usd pledged': 373.97395389999997,
#   'usd_pledged_real': 384.30971225762886},
#  {'_id': 1722631461,
#   'name': 'eResto : Restaurateurs, reprenez la maitrise !!!',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 14, 0, 0),
#   'goal': 30000,
#   'launched': datetime.datetime(2015, 6, 23, 22, 6, 40),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1058418340,
#   'name': 'Le Chat et la Chouette',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 27, 0, 0),
#   'goal': 5000,
#   'launched': datetime.datetime(2015, 5, 27, 8, 0, 50),
#   'pledged': 5175,
#   'state': 'successful',
#   'backers': 27,
#   'country': 'FR',
#   'usd pledged': 5666.73051825,
#   'usd_pledged_real': 5742.1523917313025},
#  {'_id': 1821949910,
#   'name': 'park my bike',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 4, 0, 0),
#   'goal': 9000,
#   'launched': datetime.datetime(2015, 8, 15, 0, 58, 28),
#   'pledged': 301,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'FR',
#   'usd pledged': 335.38351896,
#   'usd_pledged_real': 335.2527761380217},
#  {'_id': 166445711,
#   'name': 'Fontyou ï¿½ Simplify your typographic life',
#   'category': 'Typography',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 1, 0, 0),
#   'goal': 25000,
#   'launched': datetime.datetime(2015, 5, 27, 8, 38, 59),
#   'pledged': 25525,
#   'state': 'successful',
#   'backers': 277,
#   'country': 'FR',
#   'usd pledged': 27950.39545475,
#   'usd_pledged_real': 28322.403825882408},
#  {'_id': 1121938624,
#   'name': 'Poil de carotte',
#   'category': 'Performances',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 24, 0, 0),
#   'goal': 38000,
#   'launched': datetime.datetime(2015, 9, 25, 11, 39, 8),
#   'pledged': 258,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 288.49701899999997,
#   'usd_pledged_real': 272.96387989589283},
#  {'_id': 27628079,
#   'name': 'Fifties Cosmetics Parfumerie Ind?pendante',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 14, 0, 0),
#   'goal': 3000,
#   'launched': datetime.datetime(2015, 6, 9, 19, 22, 43),
#   'pledged': 3150,
#   'state': 'successful',
#   'backers': 36,
#   'country': 'FR',
#   'usd pledged': 3496.2745229999996,
#   'usd_pledged_real': 3430.0274402195228},
#  {'_id': 1674163196,
#   'name': '3d shingeki no kyojin map',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 3, 0, 0),
#   'goal': 350,
#   'launched': datetime.datetime(2015, 6, 3, 20, 29, 5),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 562220091,
#   'name': 'Tokyo Reverse La Suite',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 2, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 5, 27, 8, 8, 51),
#   'pledged': 944,
#   'state': 'failed',
#   'backers': 21,
#   'country': 'FR',
#   'usd pledged': 1033.69924816,
#   'usd_pledged_real': 1047.457363824995},
#  {'_id': 1114030850,
#   'name': 'GOOD (OIYAA) START',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 5, 0, 0),
#   'goal': 500,
#   'launched': datetime.datetime(2015, 8, 11, 19, 44, 17),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.09659584,
#   'usd_pledged_real': 1.1267986523488118},
#  {'_id': 282111032,
#   'name': 'Tunhell',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 14, 0, 0),
#   'goal': 3000,
#   'launched': datetime.datetime(2015, 6, 14, 21, 8, 36),
#   'pledged': 9504,
#   'state': 'successful',
#   'backers': 459,
#   'country': 'FR',
#   'usd pledged': 10707.42936384,
#   'usd_pledged_real': 10348.88279106233},
#  {'_id': 201728521,
#   'name': 'ALBA, a Romantic Fantasy Novel...',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 2, 11, 0, 0),
#   'goal': 500,
#   'launched': datetime.datetime(2015, 12, 13, 17, 52, 52),
#   'pledged': 72,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 79.14975552,
#   'usd_pledged_real': 81.17981328642944},
#  {'_id': 169131363,
#   'name': 'Cuisinez-vous le fran?ais?',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 13, 0, 0),
#   'goal': 5000,
#   'launched': datetime.datetime(2015, 10, 14, 14, 17, 7),
#   'pledged': 50,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 56.788109999999996,
#   'usd_pledged_real': 53.820154571483926},
#  {'_id': 1031033139,
#   'name': 'Bouteilles or vin ros? / Bottles of rose wine (Suspended)',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 2, 14, 0, 0),
#   'goal': 10000,
#   'launched': datetime.datetime(2015, 12, 16, 19, 13, 18),
#   'pledged': 0,
#   'state': 'suspended',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 476603680,
#   'name': 'Planeta Ginga Film Festival',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 9, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2015, 9, 14, 1, 51, 58),
#   'pledged': 1201,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 1361.65330228,
#   'usd_pledged_real': 1364.5711428993445},
#  {'_id': 1982275057,
#   'name': 'Casque de moto/scooter vintage en li?ge',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 1, 2, 0, 0),
#   'goal': 50000,
#   'launched': datetime.datetime(2015, 12, 4, 11, 23),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 355235395,
#   'name': 'Why Theatre',
#   'category': 'Spaces',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 21, 0, 0),
#   'goal': 4200,
#   'launched': datetime.datetime(2015, 6, 8, 9, 9, 36),
#   'pledged': 4230,
#   'state': 'successful',
#   'backers': 41,
#   'country': 'FR',
#   'usd pledged': 4701.0237822,
#   'usd_pledged_real': 4627.198739826727},
#  {'_id': 678294728,
#   'name': 'Invite-only Dating App for unique quality dates (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 12, 0, 0),
#   'goal': 6500,
#   'launched': datetime.datetime(2015, 7, 2, 16, 53, 44),
#   'pledged': 1065,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 1185.84072555,
#   'usd_pledged_real': 1159.6759440742196},
#  {'_id': 1678794458,
#   'name': 'Polaroids from France',
#   'category': 'Places',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 20, 0, 0),
#   'goal': 500,
#   'launched': datetime.datetime(2015, 8, 31, 18, 25, 35),
#   'pledged': 10,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 11.1819175,
#   'usd_pledged_real': 11.151006935926313},
#  {'_id': 2029690838,
#   'name': 'Ambasdr.  Learn to the world how to use social media.',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 11, 0, 0),
#   'goal': 3500,
#   'launched': datetime.datetime(2015, 10, 12, 7, 59, 29),
#   'pledged': 2007,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 2279.7362475,
#   'usd_pledged_real': 2160.3410044993648},
#  {'_id': 208665246,
#   'name': "'' Album''Eyes to Eyes''of Kilimandjaro' '",
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 1, 31, 0, 0),
#   'goal': 8000,
#   'launched': datetime.datetime(2015, 12, 6, 22, 52, 38),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1159985516,
#   'name': '888bijouï¿½ le cadeau id?al : design, chance, amour et chic',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 14, 0, 0),
#   'goal': 2888,
#   'launched': datetime.datetime(2015, 5, 27, 7, 37, 47),
#   'pledged': 3336,
#   'state': 'successful',
#   'backers': 34,
#   'country': 'FR',
#   'usd pledged': 3652.98802104,
#   'usd_pledged_real': 3632.5623938324843},
#  {'_id': 2103464588,
#   'name': 'Wings of Justice',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 13, 0, 0),
#   'goal': 2200,
#   'launched': datetime.datetime(2015, 8, 10, 16, 30, 18),
#   'pledged': 556,
#   'state': 'failed',
#   'backers': 32,
#   'country': 'FR',
#   'usd pledged': 609.7246676,
#   'usd_pledged_real': 634.8988843593345},
#  {'_id': 1254718606,
#   'name': "Heart of Ice gamebook Collector's Edition (English / French)",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 10, 0, 0),
#   'goal': 2000,
#   'launched': datetime.datetime(2015, 8, 26, 15, 18, 49),
#   'pledged': 4654,
#   'state': 'successful',
#   'backers': 125,
#   'country': 'FR',
#   'usd pledged': 5367.8672866000015,
#   'usd_pledged_real': 5244.120928031371},
#  {'_id': 1740138844,
#   'name': 'Abaros - Leather Belt',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 29, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2015, 11, 24, 15, 46, 50),
#   'pledged': 15289,
#   'state': 'successful',
#   'backers': 175,
#   'country': 'FR',
#   'usd pledged': 16224.93539914,
#   'usd_pledged_real': 16645.074194637084},
#  {'_id': 824679072,
#   'name': 'Custom boxwood dice made in Jura',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 6, 0, 0),
#   'goal': 1500,
#   'launched': datetime.datetime(2015, 10, 7, 0, 41, 31),
#   'pledged': 365,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 410.27785215,
#   'usd_pledged_real': 396.53655197888037},
#  {'_id': 436973805,
#   'name': "My 2016, l'agenda de votre ann?e",
#   'category': 'Calendars',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 2, 0, 0),
#   'goal': 1200,
#   'launched': datetime.datetime(2015, 11, 10, 0, 2),
#   'pledged': 1767,
#   'state': 'successful',
#   'backers': 69,
#   'country': 'FR',
#   'usd pledged': 1897.96733649,
#   'usd_pledged_real': 1926.3894642740336},
#  {'_id': 1707789341,
#   'name': 'New World Vision',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 11, 0, 0),
#   'goal': 10000,
#   'launched': datetime.datetime(2015, 10, 2, 20, 31, 4),
#   'pledged': 31,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 34.61100028,
#   'usd_pledged_real': 33.368495834320036},
#  {'_id': 1807647480,
#   'name': 'DONUTS FACTORY',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 14, 0, 0),
#   'goal': 90000,
#   'launched': datetime.datetime(2015, 6, 9, 15, 39, 20),
#   'pledged': 192,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'FR',
#   'usd pledged': 213.10625664,
#   'usd_pledged_real': 209.0683392133804},
#  {'_id': 504259167,
#   'name': '"les recettes" : world food drawing and recipe on shirt',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 13, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 9, 24, 1, 19, 59),
#   'pledged': 130,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 145.6372138,
#   'usd_pledged_real': 139.9324018858582},
#  {'_id': 1711978703,
#   'name': 'TikiOne Steam Cleaner (Canceled)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 2, 0, 0),
#   'goal': 2500,
#   'launched': datetime.datetime(2015, 8, 3, 22, 9, 21),
#   'pledged': 163,
#   'state': 'canceled',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 179.15552821,
#   'usd_pledged_real': 181.9074615539138},
#  {'_id': 414964217,
#   'name': 'Youfigure3D',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 19, 0, 0),
#   'goal': 44,
#   'launched': datetime.datetime(2015, 6, 24, 12, 5, 24),
#   'pledged': 446,
#   'state': 'successful',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 503.26444652,
#   'usd_pledged_real': 487.8795834427234},
#  {'_id': 2094487330,
#   'name': 'TPT (Tunisian Public Transport)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 1, 0, 0),
#   'goal': 1546,
#   'launched': datetime.datetime(2015, 7, 2, 15, 11, 18),
#   'pledged': 5,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.56732735,
#   'usd_pledged_real': 5.470519371109092},
#  {'_id': 18939379,
#   'name': 'The Reversible Tie - La Cravate R?versible | Oh My Node',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 26, 0, 0),
#   'goal': 10000,
#   'launched': datetime.datetime(2015, 5, 27, 6, 25, 25),
#   'pledged': 10968,
#   'state': 'successful',
#   'backers': 100,
#   'country': 'FR',
#   'usd pledged': 12010.18363752,
#   'usd_pledged_real': 12286.322392741124},
#  {'_id': 1152345794,
#   'name': 'CREOLE SOUL',
#   'category': 'Ready-to-wear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 1, 14, 0, 0),
#   'goal': 30000,
#   'launched': datetime.datetime(2015, 11, 25, 20, 53, 40),
#   'pledged': 525,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 558.25882875,
#   'usd_pledged_real': 572.9877216916782},
#  {'_id': 279280557,
#   'name': 'Zmei - Leather Goods & Accessories for Apple Watch & iPhone',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 1, 15, 0, 0),
#   'goal': 6500,
#   'launched': datetime.datetime(2015, 12, 16, 16, 20, 21),
#   'pledged': 989,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'FR',
#   'usd pledged': 1088.56086958,
#   'usd_pledged_real': 1079.399727148704},
#  {'_id': 499044406,
#   'name': 'Faire na?tre un violoncelle pour faire ?clore un talent',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 12, 0, 0),
#   'goal': 29000,
#   'launched': datetime.datetime(2015, 5, 28, 5, 55, 19),
#   'pledged': 35032,
#   'state': 'successful',
#   'backers': 193,
#   'country': 'FR',
#   'usd pledged': 38360.75430248,
#   'usd_pledged_real': 38146.26072564136},
#  {'_id': 635253293,
#   'name': 'Kling | Smartphone ring and grip holder (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 31, 0, 0),
#   'goal': 7000,
#   'launched': datetime.datetime(2015, 6, 19, 15, 30, 42),
#   'pledged': 1411,
#   'state': 'canceled',
#   'backers': 59,
#   'country': 'FR',
#   'usd pledged': 1602.49129698,
#   'usd_pledged_real': 1547.4375705997827},
#  {'_id': 998248740,
#   'name': 'Wamaw Wallet : The minimalist leather card-holder handmade',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 19, 0, 0),
#   'goal': 1800,
#   'launched': datetime.datetime(2015, 9, 17, 19, 36, 49),
#   'pledged': 1806,
#   'state': 'successful',
#   'backers': 79,
#   'country': 'FR',
#   'usd pledged': 2038.24358136,
#   'usd_pledged_real': 2001.7734426956326},
#  {'_id': 1785964163,
#   'name': 'Tom and Jey - Made To Measure Bamboo Custom Dress Shirts',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 3, 0, 0),
#   'goal': 10000,
#   'launched': datetime.datetime(2015, 10, 31, 19, 4),
#   'pledged': 10649,
#   'state': 'successful',
#   'backers': 72,
#   'country': 'FR',
#   'usd pledged': 11693.5917800995,
#   'usd_pledged_real': 11609.630857117936},
#  {'_id': 339897138,
#   'name': 'XV Academy, rugby on a boardgame',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 16, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2015, 10, 17, 16, 17, 48),
#   'pledged': 623,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'FR',
#   'usd pledged': 708.72044523,
#   'usd_pledged_real': 665.8615050821372},
#  {'_id': 2100439267,
#   'name': "Fabled Lands: The Serpent King's Domain",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 3, 0, 0),
#   'goal': 5000,
#   'launched': datetime.datetime(2015, 7, 8, 18, 1, 50),
#   'pledged': 30589,
#   'state': 'successful',
#   'backers': 513,
#   'country': 'FR',
#   'usd pledged': 33759.785324419,
#   'usd_pledged_real': 33467.65281895863},
# ...
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 64050173,
#   'name': "Cr?ation d'une boutique bijoux et mode",
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 29, 0, 0),
#   'goal': 30000,
#   'launched': datetime.datetime(2015, 9, 25, 12, 35, 8),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1133857635,
#   'name': "Les Lettres de l'Alphabet, jeu ?ducatif pour enfants",
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 1, 8, 0, 0),
#   'goal': 3000,
#   'launched': datetime.datetime(2015, 12, 9, 8, 46, 21),
#   'pledged': 5,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.42664265,
#   'usd_pledged_real': 5.4304736459113965},
#  {'_id': 2118888011,
#   'name': 'LUNA - Luxury Sleep Mask with NAP & Lucid Dream Features',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 3, 0, 0),
#   'goal': 25000,
#   'launched': datetime.datetime(2015, 5, 29, 2, 9, 24),
#   'pledged': 13072,
#   'state': 'canceled',
#   'backers': 120,
#   'country': 'FR',
#   'usd pledged': 14217.17961888,
#   'usd_pledged_real': 14504.621461780012},
#  {'_id': 1556193939,
#   'name': 'The Album To Support French community for black friday',
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 1, 13, 0, 0),
#   'goal': 35000,
#   'launched': datetime.datetime(2015, 11, 14, 17, 2, 3),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 977207362,
#   'name': 'Zoby Z?',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 5, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 7, 22, 22, 33, 19),
#   'pledged': 292,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 316.24971232,
#   'usd_pledged_real': 329.02520648585306},
#  {'_id': 1325039752,
#   'name': 'No Gig Impossible : uchronian dream gigs, collector posters.',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 25, 0, 0),
#   'goal': 9710,
#   'launched': datetime.datetime(2015, 11, 25, 18, 36, 29),
#   'pledged': 125,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 132.91876875,
#   'usd_pledged_real': 136.087008589812},
#  {'_id': 197599880,
#   'name': 'THE DEVIL DOGS',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 27, 0, 0),
#   'goal': 30000,
#   'launched': datetime.datetime(2015, 5, 28, 21, 11, 25),
#   'pledged': 30320,
#   'state': 'successful',
#   'backers': 105,
#   'country': 'FR',
#   'usd pledged': 32976.1999728,
#   'usd_pledged_real': 33251.81228957152},
#  {'_id': 2018078323,
#   'name': 'Kitchen Trotter : un voyage ? cuisiner - a trip to cook !',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 10, 0, 0),
#   'goal': 20000,
#   'launched': datetime.datetime(2015, 5, 27, 8, 12, 55),
#   'pledged': 20689,
#   'state': 'successful',
#   'backers': 359,
#   'country': 'FR',
#   'usd pledged': 22654.87684871,
#   'usd_pledged_real': 23140.763939377},
#  {'_id': 813865095,
#   'name': 'Komodor: V?tements graphiques de qualit? design?s en France',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 14, 0, 0),
#   'goal': 5500,
#   'launched': datetime.datetime(2015, 9, 14, 10, 0, 52),
#   'pledged': 1642,
#   'state': 'failed',
#   'backers': 31,
#   'country': 'FR',
#   'usd pledged': 1861.64423176,
#   'usd_pledged_real': 1865.3155814059164},
#  {'_id': 1593053116,
#   'name': 'The Prophecy of Amat (Canceled)',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 6, 0, 0),
#   'goal': 6000,
#   'launched': datetime.datetime(2015, 11, 6, 15, 5, 17),
#   'pledged': 680,
#   'state': 'canceled',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 739.2469447999997,
#   'usd_pledged_real': 744.6016381236038},
#  {'_id': 1878604968,
#   'name': 'VARIATIONS',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 24, 0, 0),
#   'goal': 8000,
#   'launched': datetime.datetime(2015, 9, 21, 21, 59, 22),
#   'pledged': 12,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 13.56407328,
#   'usd_pledged_real': 13.220372594167616},
#  {'_id': 530682273,
#   'name': 'Rendons ? Marie-Antoinette...son ?pinette',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 14, 0, 0),
#   'goal': 35000,
#   'launched': datetime.datetime(2015, 8, 30, 16, 34, 53),
#   'pledged': 51,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 57.02777925,
#   'usd_pledged_real': 57.93611123733358},
#  {'_id': 726258998,
#   'name': 'Customisation Sneakers',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 9, 0, 0),
#   'goal': 1000,
#   'launched': datetime.datetime(2015, 9, 23, 9, 41, 17),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1388326878,
#   'name': 'REFLEXION CONTRE NATURE',
#   'category': 'Nature',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 5, 0, 0),
#   'goal': 2500,
#   'launched': datetime.datetime(2015, 6, 14, 21, 6, 23),
#   'pledged': 2519,
#   'state': 'successful',
#   'backers': 22,
#   'country': 'FR',
#   'usd pledged': 2837.96449574,
#   'usd_pledged_real': 2817.5157988926794},
#  {'_id': 679439475,
#   'name': 'SOLAR KIT BOX & BATTERY UNIT: Save On Your Electricity Bill!',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 23, 0, 0),
#   'goal': 25000,
#   'launched': datetime.datetime(2015, 6, 23, 23, 40, 42),
#   'pledged': 8683,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'FR',
#   'usd pledged': 9878.93381557,
#   'usd_pledged_real': 9498.337271374814},
#  {'_id': 148873286,
#   'name': 'Ride Europe and USA to Dance the World',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 26, 0, 0),
#   'goal': 25000,
#   'launched': datetime.datetime(2015, 8, 11, 19, 29, 52),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1674716636,
#   'name': 'Aller voir mes 2 seuls amis en suisse',
#   'category': 'Nature',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2016, 1, 18, 0, 0),
#   'goal': 1100,
#   'launched': datetime.datetime(2015, 11, 19, 4, 38, 55),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 781355584,
#   'name': 'Reportage sur Mr Mickey Mouse',
#   'category': 'Video',
#   'main_category': 'Journalism',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 6, 30, 0, 0),
#   'goal': 400,
#   'launched': datetime.datetime(2015, 6, 21, 18, 33, 41),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 916472687,
#   'name': 'Imprimerie 3D - Fablab en zone rurale',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 31, 0, 0),
#   'goal': 3000,
#   'launched': datetime.datetime(2015, 6, 18, 16, 21, 51),
#   'pledged': 100,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 112.539867,
#   'usd_pledged_real': 109.66956559885062},
#  {'_id': 263025244,
#   'name': 'UnitMaker',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 18, 0, 0),
#   'goal': 4000,
#   'launched': datetime.datetime(2015, 8, 19, 8, 38, 19),
#   'pledged': 85,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 94.16383640000001,
#   'usd_pledged_real': 97.06187980313568},
#  {'_id': 2101577594,
#   'name': 'Cold Blooded',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 22, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2015, 6, 22, 11, 49, 13),
#   'pledged': 517,
#   'state': 'failed',
#   'backers': 34,
#   'country': 'FR',
#   'usd pledged': 586.9197521000001,
#   'usd_pledged_real': 565.5465126454887},
#  {'_id': 2146589298,
#   'name': 'Tutoriel complet Aquarium Juwel 450 vision ultra plant?',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 22, 0, 0),
#   'goal': 4000,
#   'launched': datetime.datetime(2015, 10, 23, 0, 28, 25),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 831858023,
#   'name': 'Deleez Cookies (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 16, 0, 0),
#   'goal': 1000,
#   'launched': datetime.datetime(2015, 11, 16, 21, 35, 20),
#   'pledged': 86,
#   'state': 'canceled',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 92.6326855,
#   'usd_pledged_real': 93.18957577071028},
#  {'_id': 1887864427,
#   'name': 'The First International B2B Networking Platform.',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 5, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2015, 7, 6, 18, 31, 59),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1316370878,
#   'name': 'MUSE DELTA',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 21, 0, 0),
#   'goal': 90000,
#   'launched': datetime.datetime(2015, 10, 22, 18, 20, 58),
#   'pledged': 1415,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'FR',
#   'usd pledged': 1607.249541,
#   'usd_pledged_real': 1497.0693412894898},
#  {'_id': 1089062782,
#   'name': 'APPARENCES: a photography project about people and light',
#   'category': 'People',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 21, 0, 0),
#   'goal': 2000,
#   'launched': datetime.datetime(2015, 8, 7, 23, 40, 19),
#   'pledged': 2108,
#   'state': 'successful',
#   'backers': 25,
#   'country': 'FR',
#   'usd pledged': 2298.77286168,
#   'usd_pledged_real': 2350.632262093267},
#  {'_id': 1327570430,
#   'name': 'r?n',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 18, 0, 0),
#   'goal': 60000,
#   'launched': datetime.datetime(2015, 6, 18, 17, 55, 55),
#   'pledged': 86,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 96.78428562,
#   'usd_pledged_real': 94.0754353723637},
#  {'_id': 1033114039,
#   'name': 'C&G (Canceled)',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 7, 13, 0, 0),
#   'goal': 29000,
#   'launched': datetime.datetime(2015, 6, 5, 12, 45, 16),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 109832866,
#   'name': 'New PC Game Hit Tank PRO Steam Greenlight Need help !!!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 14, 0, 0),
#   'goal': 1500,
#   'launched': datetime.datetime(2015, 10, 15, 17, 41, 34),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.13906244,
#   'usd_pledged_real': 1.0687985635347306},
#  {'_id': 688601772,
#   'name': 'Stephen Hawking Hologram Project',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 9, 15, 0, 0),
#   'goal': 15000,
#   'launched': datetime.datetime(2015, 7, 21, 9, 16, 56),
#   'pledged': 1108,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'FR',
#   'usd pledged': 1199.44315136,
#   'usd_pledged_real': 1265.2301508455805},
#  {'_id': 205663955,
#   'name': "Cr?ation d'un atelier de costume ind?pendant",
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 26, 0, 0),
#   'goal': 1500,
#   'launched': datetime.datetime(2015, 7, 27, 18, 20, 54),
#   'pledged': 1841,
#   'state': 'successful',
#   'backers': 26,
#   'country': 'FR',
#   'usd pledged': 2021.37985448,
#   'usd_pledged_real': 2074.4363189741625},
#  {'_id': 1170494966,
#   'name': 'a Family of Grave Diggers (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 9, 0, 0),
#   'goal': 6000,
#   'launched': datetime.datetime(2015, 7, 11, 18, 7, 55),
#   'pledged': 174,
#   'state': 'canceled',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 192.90743682,
#   'usd_pledged_real': 194.37431578006652},
#  {'_id': 587734625,
#   'name': 'The Bakounines (2016) - 2nd EP !',
#   'category': 'Punk',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 13, 0, 0),
#   'goal': 700,
#   'launched': datetime.datetime(2015, 10, 19, 14, 12, 14),
#   'pledged': 770,
#   'state': 'successful',
#   'backers': 14,
#   'country': 'FR',
#   'usd pledged': 873.8669555,
#   'usd_pledged_real': 834.3717830633365},
#  {'_id': 83153281,
#   'name': 'Wram - Handcrafted full grain leather wallet and card-holder',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 7, 0, 0),
#   'goal': 1200,
#   'launched': datetime.datetime(2015, 10, 8, 15, 39, 54),
#   'pledged': 3685,
#   'state': 'successful',
#   'backers': 104,
#   'country': 'FR',
#   'usd pledged': 4153.66180075,
#   'usd_pledged_real': 3966.5453919183656},
#  {'_id': 12134418,
#   'name': 'New AMIGA 1200 Cases (Made From New Molds)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 11, 1, 0, 0),
#   'goal': 125000,
#   'launched': datetime.datetime(2015, 9, 2, 12, 0, 19),
#   'pledged': 156310,
#   'state': 'successful',
#   'backers': 840,
#   'country': 'FR',
#   'usd pledged': 176145.799052405,
#   'usd_pledged_real': 169815.44211109538},
#  {'_id': 508223995,
#   'name': 'Sijak Taekwondo Card Game / Jeu de Cartes (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 12, 14, 0, 0),
#   'goal': 6500,
#   'launched': datetime.datetime(2015, 11, 21, 18, 20, 23),
#   'pledged': 1340,
#   'state': 'canceled',
#   'backers': 28,
#   'country': 'FR',
#   'usd pledged': 1435.6117470000006,
#   'usd_pledged_real': 1452.0236224738587},
#  {'_id': 299205964,
#   'name': '10 ans de Mariage ! - Spectacle com?die au Qu?bec (Canceled)',
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 10, 5, 0, 0),
#   'goal': 2000,
#   'launched': datetime.datetime(2015, 9, 9, 19, 37, 12),
#   'pledged': 130,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 145.1299421,
#   'usd_pledged_real': 147.70545260359262},
#  {'_id': 1115857606,
#   'name': 'Saint-Matthieu',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': datetime.datetime(2015, 8, 19, 0, 0),
#   'goal': 99,
#   'launched': datetime.datetime(2015, 7, 20, 20, 49, 42),
#   'pledged': 100,
#   'state': 'successful',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 108.29918300000001,
#   'usd_pledged_real': 112.80952112358284}]

# %% [markdown]
# ## Question 5

# %%
number_usa_project = collection.find({"$and" : [ {"country":"US"}, {"goal": {"$gte" : 200000}}]})
list(number_usa_project)
# Out:
# [{'_id': 655043686,
#   'name': 'Far from Par is a movie about a man and a talking golf ball.',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 12, 5, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2014, 10, 6, 21, 20, 6),
#   'pledged': 10,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 866634482,
#   'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 9, 14, 0, 0),
#   'goal': 287000,
#   'launched': datetime.datetime(2012, 8, 13, 23, 14, 2),
#   'pledged': 1465,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 1465.0,
#   'usd_pledged_real': 1465.0},
#  {'_id': 993194166,
#   'name': 'Storybricks, the storytelling online RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 6, 1, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2012, 5, 1, 20, 49, 58),
#   'pledged': 23680,
#   'state': 'failed',
#   'backers': 409,
#   'country': 'US',
#   'usd pledged': 23680.54,
#   'usd_pledged_real': 23680.54},
#  {'_id': 1147175344,
#   'name': 'Shine On New World',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 11, 4, 0, 0),
#   'goal': 300000,
#   'launched': datetime.datetime(2013, 9, 30, 18, 18, 40),
#   'pledged': 12314,
#   'state': 'failed',
#   'backers': 50,
#   'country': 'US',
#   'usd pledged': 12314.0,
#   'usd_pledged_real': 12314.0},
#  {'_id': 2012810303,
#   'name': 'Nightclub',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 9, 10, 0, 0),
#   'goal': 3000000,
#   'launched': datetime.datetime(2017, 8, 11, 18, 8, 7),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 593221398,
#   'name': 'Nastaran (Wild Rose)',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 6, 30, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2015, 5, 8, 21, 3, 20),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 621936552,
#   'name': 'Hubo - Extension Box for iPhone',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 11, 26, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2016, 10, 27, 17, 43, 14),
#   'pledged': 1996,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 438.0,
#   'usd_pledged_real': 1996.0},
#  {'_id': 1323150226,
#   'name': 'Baja ATV Park (Suspended)',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 5, 31, 0, 0),
#   'goal': 300000,
#   'launched': datetime.datetime(2016, 4, 1, 22, 4, 54),
#   'pledged': 11,
#   'state': 'suspended',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 61436443,
#   'name': 'Chihuly Installation for Orlando (Pulse Nightclub)',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 8, 12, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2016, 7, 13, 17, 31, 26),
#   'pledged': 5,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 4.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 821637012,
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 3, 10, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2015, 2, 10, 14, 5, 34),
#   'pledged': 300319,
#   'state': 'successful',
#   'backers': 3755,
#   'country': 'US',
#   'usd pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': 924370408,
#   'name': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 12, 15, 0, 0),
#   'goal': 3000000,
#   'launched': datetime.datetime(2016, 11, 15, 21, 6, 46),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 966762561,
#   'name': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 12, 12, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2012, 11, 12, 23, 27, 51),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 673847752,
#   'name': 'Saints of The Classroom',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 11, 18, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2016, 10, 19, 2, 5, 16),
#   'pledged': 3085,
#   'state': 'failed',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 1915.0,
#   'usd_pledged_real': 3085.0},
#  {'_id': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 1, 23, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2014, 12, 10, 18, 58, 8),
#   'pledged': 342471,
#   'state': 'successful',
#   'backers': 1096,
#   'country': 'US',
#   'usd pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': 1529289950,
#   'name': 'Breakfast 24/7',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 7, 2, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2016, 5, 18, 0, 36, 35),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 314981144,
#   'name': 'FJE REVOLT',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 2, 10, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2015, 1, 14, 3, 1, 52),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 208383561,
#   'name': 'Austin City Limits 40 Year History Documentary Film',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 9, 30, 0, 0),
#   'goal': 400000,
#   'launched': datetime.datetime(2014, 8, 29, 20, 46, 59),
#   'pledged': 9,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 9.0,
#   'usd_pledged_real': 9.0},
#  {'_id': 912070501,
#   'name': 'Ozark Mountain Ranch',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 4, 6, 0, 0),
#   'goal': 466000,
#   'launched': datetime.datetime(2015, 2, 10, 19, 11, 52),
#   'pledged': 1076,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 1076.0,
#   'usd_pledged_real': 1076.0},
#  {'_id': 2116069761,
#   'name': 'STEM Lesson Plan - BotBrainï¿½ Educational Products',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 10, 7, 0, 0),
#   'goal': 279646,
#   'launched': datetime.datetime(2014, 9, 4, 18, 26, 25),
#   'pledged': 85,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 85.0,
#   'usd_pledged_real': 85.0},
#  {'_id': 410799527,
#   'name': 'Guitar Godz VR: A 3D Rock Music Game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 4, 4, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2017, 3, 28, 19, 0, 52),
#   'pledged': 22612,
#   'state': 'failed',
#   'backers': 36,
#   'country': 'US',
#   'usd pledged': 12311.0,
#   'usd_pledged_real': 22612.0},
#  {'_id': 848767036,
#   'name': "The world's first crowd funded millionaire documentary",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 5, 24, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2015, 4, 24, 2, 58, 26),
#   'pledged': 171,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 171.0,
#   'usd_pledged_real': 171.0},
#  {'_id': 1520402606,
#   'name': 'Creating an online game, "Perdition Online".',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 11, 15, 0, 0),
#   'goal': 350000,
#   'launched': datetime.datetime(2013, 9, 16, 22, 49, 11),
#   'pledged': 16,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': 376621995,
#   'name': 'The Adventures of Billy Buskirk',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 10, 14, 0, 0),
#   'goal': 750000,
#   'launched': datetime.datetime(2017, 8, 15, 19, 49, 31),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1227415659,
#   'name': 'MY TINSEL TOWN (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 9, 13, 0, 0),
#   'goal': 577000,
#   'launched': datetime.datetime(2014, 7, 15, 0, 55, 45),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 520101512,
#   'name': 'Moonlight 5 star (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 6, 18, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2016, 4, 19, 6, 41, 47),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1681174007,
#   'name': 'TOMB Adventure 2',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 7, 16, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2012, 6, 8, 16, 54, 47),
#   'pledged': 5740,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'US',
#   'usd pledged': 5740.0,
#   'usd_pledged_real': 5740.0},
#  {'_id': 1038309030,
#   'name': 'The EIFLE S Smart-Mirror W/Front-Facing Camera! (Canceled)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 3, 25, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2016, 1, 25, 15, 17, 42),
#   'pledged': 4248,
#   'state': 'canceled',
#   'backers': 16,
#   'country': 'US',
#   'usd pledged': 4248.0,
#   'usd_pledged_real': 4248.0},
#  {'_id': 1496553278,
#   'name': 'The Brick Cafe',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 3, 1, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2016, 1, 28, 17, 43, 17),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1256627633,
#   'name': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 6, 26, 0, 0),
#   'goal': 400000,
#   'launched': datetime.datetime(2016, 5, 27, 17, 52, 3),
#   'pledged': 146,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 146.0,
#   'usd_pledged_real': 146.0},
#  {'_id': 2033979252,
#   'name': 'ViewCoze.com | Cozy viewing from home (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 2, 1, 0, 0),
#   'goal': 370000,
#   'launched': datetime.datetime(2015, 12, 10, 23, 55, 54),
#   'pledged': 80,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 80.0,
#   'usd_pledged_real': 80.0},
#  {'_id': 1751639331,
#   'name': 'Meet kubo: an electric scooter to carry all your stuff!',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 12, 20, 0, 0),
#   'goal': 300000,
#   'launched': datetime.datetime(2013, 11, 20, 6, 0, 7),
#   'pledged': 56667,
#   'state': 'failed',
#   'backers': 166,
#   'country': 'US',
#   'usd pledged': 56667.0,
#   'usd_pledged_real': 56667.0},
#  {'_id': 1178067412,
#   'name': 'ONEIDNET Social Professional Commercial Corporate Platform',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 3, 24, 0, 0),
#   'goal': 545539,
#   'launched': datetime.datetime(2017, 2, 22, 19, 24, 24),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 175370281,
#   'name': 'Civilian Cam',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 10, 6, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2015, 8, 7, 22, 42, 57),
#   'pledged': 10,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 499583381,
#   'name': 'The Scariest Movie Ever Created',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 8, 22, 0, 0),
#   'goal': 100000000,
#   'launched': datetime.datetime(2015, 7, 23, 21, 44, 2),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 290390319,
#   'name': 'The SEED Project',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 1, 17, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2012, 12, 18, 23, 1, 12),
#   'pledged': 35,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 1560972255,
#   'name': 'NewsRadio Season 6 (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 12, 16, 0, 0),
#   'goal': 3000000,
#   'launched': datetime.datetime(2015, 10, 17, 0, 40, 32),
#   'pledged': 101,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 101.0,
#   'usd_pledged_real': 101.0},
#  {'_id': 1876072493,
#   'name': 'Get Me Me Kids (Books, Music, Film & Games)',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 10, 10, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2015, 9, 10, 22, 58, 39),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1517530930,
#   'name': "Daniel's Dream",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 6, 21, 0, 0),
#   'goal': 2000000,
#   'launched': datetime.datetime(2013, 5, 22, 22, 2, 9),
#   'pledged': 60,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': 658943325,
#   'name': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 12, 16, 0, 0),
#   'goal': 444000,
#   'launched': datetime.datetime(2012, 11, 5, 19, 5, 56),
#   'pledged': 3439,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 3439.0,
#   'usd_pledged_real': 3439.0},
#  {'_id': 420095150,
#   'name': 'GolferVox',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 7, 23, 0, 0),
#   'goal': 1200000,
#   'launched': datetime.datetime(2015, 6, 23, 21, 12, 43),
#   'pledged': 70,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': 668413973,
#   'name': 'Power Rangers | fan film reboot movie',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 2, 6, 0, 0),
#   'goal': 400000,
#   'launched': datetime.datetime(2015, 12, 8, 21, 34, 39),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1481048815,
#   'name': '"Another Network" Film Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 5, 15, 0, 0),
#   'goal': 225000,
#   'launched': datetime.datetime(2014, 3, 31, 22, 46, 31),
#   'pledged': 55,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 55.0,
#   'usd_pledged_real': 55.0},
#  {'_id': 1916952451,
#   'name': 'SELF-SUSTAINING ORGANIC FARM',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 12, 9, 0, 0),
#   'goal': 450000,
#   'launched': datetime.datetime(2014, 10, 10, 17, 48, 13),
#   'pledged': 11,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 1554575493,
#   'name': 'Fuel-X-Tender',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 7, 31, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2014, 7, 1, 4, 18, 43),
#   'pledged': 272,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 272.0,
#   'usd_pledged_real': 272.0},
#  {'_id': 1601085300,
#   'name': 'Salad Barr ( the new fast food restaurant )',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 3, 26, 0, 0),
#   'goal': 270000,
#   'launched': datetime.datetime(2016, 2, 26, 0, 4, 18),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1636574067,
#   'name': 'We want your money (Suspended)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 8, 3, 0, 0),
#   'goal': 300000,
#   'launched': datetime.datetime(2016, 6, 4, 16, 51, 18),
#   'pledged': 123,
#   'state': 'suspended',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 123.0,
#   'usd_pledged_real': 123.0},
#  {'_id': 773987836,
#   'name': "Dutch's Kegs",
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 12, 22, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2015, 11, 17, 23, 36, 6),
#   'pledged': 260,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 260.0,
#   'usd_pledged_real': 260.0},
#  {'_id': 1831435950,
#   'name': 'Pro Tailgater Party Plate',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 5, 31, 0, 0),
#   'goal': 365000,
#   'launched': datetime.datetime(2017, 4, 25, 21, 25, 17),
#   'pledged': 200,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 178255149,
#   'name': 'Gabriel Device - Free energy for everyone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 12, 14, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2017, 11, 14, 1, 35, 25),
#   'pledged': 81,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 40.0,
#   'usd_pledged_real': 81.0},
#  {'_id': 1098261281,
#   'name': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 11, 30, 0, 0),
#   'goal': 875000,
#   'launched': datetime.datetime(2017, 10, 31, 6, 35, 30),
#   'pledged': 5,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 849179016,
#   'name': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 4, 25, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2017, 3, 11, 3, 10, 44),
#   'pledged': 710,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 710.0},
#  {'_id': 1855118124,
#   'name': 'Sonic Chao World fan game (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 2, 14, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2015, 1, 15, 23, 33, 34),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 326838990,
#   'name': 'StreamStick: The Future of Streaming TV and Media (Canceled)',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 8, 17, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2015, 7, 8, 18, 42, 7),
#   'pledged': 4433,
#   'state': 'canceled',
#   'backers': 26,
#   'country': 'US',
#   'usd pledged': 4433.0,
#   'usd_pledged_real': 4433.0},
#  {'_id': 607916149,
#   'name': 'The Darkest Dawn',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 6, 28, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2013, 5, 29, 4, 48, 42),
#   'pledged': 5,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 696960534,
#   'name': 'Adventure Combat Ops - A real life, apocalyptic video game!',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 7, 24, 0, 0),
#   'goal': 400000,
#   'launched': datetime.datetime(2014, 6, 24, 1, 26, 37),
#   'pledged': 320,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'_id': 966045318,
#   'name': 'Haboob Wind - The Movie',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 12, 31, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2017, 11, 16, 19, 49, 52),
#   'pledged': 125,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 125.0},
#  {'_id': 2053440575,
#   'name': "World's First Smart Football",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 5, 3, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2015, 4, 3, 1, 17, 58),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 397353040,
#   'name': 'The Maryanne Godboldo Story (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 7, 20, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2013, 6, 20, 1, 17, 50),
#   'pledged': 2350,
#   'state': 'canceled',
#   'backers': 45,
#   'country': 'US',
#   'usd pledged': 2350.0,
#   'usd_pledged_real': 2350.0},
#  {'_id': 534082236,
#   'name': 'M.A.C.S. (Canceled)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 12, 8, 0, 0),
#   'goal': 400000,
#   'launched': datetime.datetime(2014, 10, 24, 20, 53, 50),
#   'pledged': 8,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 8.0,
#   'usd_pledged_real': 8.0},
#  {'_id': 1733658269,
#   'name': 'Keeping my best friends dream alive after losing to cancer',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 8, 13, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2014, 7, 14, 16, 23, 40),
#   'pledged': 5,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 1957695328,
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 9, 14, 0, 0),
#   'goal': 900000,
#   'launched': datetime.datetime(2012, 8, 15, 21, 20, 10),
#   'pledged': 2229344,
#   'state': 'successful',
#   'backers': 44162,
#   'country': 'US',
#   'usd pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': 1618218442,
#   'name': "Pontruff's Pop Shop, Pizza, and Punk Rock",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 9, 26, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2014, 7, 28, 9, 5, 22),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1402370273,
#   'name': 'The Good Fight of Faith',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 11, 19, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2015, 10, 20, 0, 56, 49),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 410651072,
#   'name': 'Film Adaptation of "The Traveler"',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 10, 31, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2016, 10, 1, 19, 42, 33),
#   'pledged': 25,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 670536219,
#   'name': 'Boulder Creek Brewery and Cafe Rebuild (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 5, 23, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2015, 4, 15, 8, 33, 33),
#   'pledged': 12397,
#   'state': 'canceled',
#   'backers': 86,
#   'country': 'US',
#   'usd pledged': 12397.0,
#   'usd_pledged_real': 12397.0},
#  {'_id': 489938719,
#   'name': 'Uncommon Wealth',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 11, 24, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2013, 9, 25, 18, 39, 9),
#   'pledged': 2110,
#   'state': 'failed',
#   'backers': 18,
#   'country': 'US',
#   'usd pledged': 2110.0,
#   'usd_pledged_real': 2110.0},
#  {'_id': 1730464042,
#   'name': 'Design the Starship Enterprise Science Research Mock Up',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 12, 2, 0, 0),
#   'goal': 313550,
#   'launched': datetime.datetime(2013, 10, 18, 9, 18, 13),
#   'pledged': 31,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 31.0,
#   'usd_pledged_real': 31.0},
#  {'_id': 1517172285,
#   'name': 'Backyard Soccer Buddy / Football Mate (Overseas)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 9, 15, 0, 0),
#   'goal': 2000000,
#   'launched': datetime.datetime(2016, 7, 20, 18, 37, 9),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 469586156,
#   'name': 'Frickin! Fleasï¿½ Mobile Game',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 10, 28, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2017, 9, 14, 21, 41, 45),
#   'pledged': 353,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 250.0,
#   'usd_pledged_real': 353.0},
#  {'_id': 1523176093,
#   'name': '"anonymous (street meat)" (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 6, 17, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2012, 5, 18, 8, 18, 34),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1555404895,
#   'name': 'Better Days',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2011, 2, 4, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2010, 12, 6, 20, 15, 52),
#   'pledged': 50,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'_id': 851609835,
#   'name': 'Akaneiro: Demon Hunters',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 2, 3, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2013, 1, 4, 0, 27, 43),
#   'pledged': 204680,
#   'state': 'successful',
#   'backers': 2681,
#   'country': 'US',
#   'usd pledged': 204680.93,
#   'usd_pledged_real': 204680.93},
#  {'_id': 934554143,
#   'name': 'Hello Space Boy!',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 7, 31, 0, 0),
#   'goal': 2000000,
#   'launched': datetime.datetime(2016, 6, 3, 23, 59, 11),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1452500654,
#   'name': 'Interactive Breastfeeding Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2011, 9, 20, 0, 0),
#   'goal': 210000,
#   'launched': datetime.datetime(2011, 8, 2, 15, 54, 48),
#   'pledged': 12058,
#   'state': 'failed',
#   'backers': 117,
#   'country': 'US',
#   'usd pledged': 12058.3,
#   'usd_pledged_real': 12058.3},
#  {'_id': 1783703627,
#   'name': 'Aquaponics system for supplying fresh organic food.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 6, 5, 0, 0),
#   'goal': 8000000,
#   'launched': datetime.datetime(2016, 4, 6, 20, 30, 5),
#   'pledged': 21,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 21.0,
#   'usd_pledged_real': 21.0},
#  {'_id': 1028997654,
#   'name': 'After Reset RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 12, 11, 0, 0),
#   'goal': 900000,
#   'launched': datetime.datetime(2013, 11, 11, 10, 41, 59),
#   'pledged': 47939,
#   'state': 'failed',
#   'backers': 1362,
#   'country': 'US',
#   'usd pledged': 47939.0,
#   'usd_pledged_real': 47939.0},
#  {'_id': 731780695,
#   'name': 'SLAYING GIANTS #GOLIATH',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 8, 20, 0, 0),
#   'goal': 350000,
#   'launched': datetime.datetime(2016, 7, 21, 3, 42, 14),
#   'pledged': 2508,
#   'state': 'failed',
#   'backers': 26,
#   'country': 'US',
#   'usd pledged': 175.0,
#   'usd_pledged_real': 2508.0},
#  {'_id': 776004598,
#   'name': 'Fan News',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 3, 19, 0, 0),
#   'goal': 275000,
#   'launched': datetime.datetime(2015, 2, 17, 19, 40, 55),
#   'pledged': 10,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 580110957,
#   'name': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 11, 5, 0, 0),
#   'goal': 350000,
#   'launched': datetime.datetime(2016, 9, 21, 20, 21, 50),
#   'pledged': 1865,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1865.0},
#  {'_id': 644614031,
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 8, 14, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2014, 7, 15, 8, 19, 5),
#   'pledged': 282155,
#   'state': 'successful',
#   'backers': 1657,
#   'country': 'US',
#   'usd pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': 281465042,
#   'name': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 6, 15, 0, 0),
#   'goal': 2000000,
#   'launched': datetime.datetime(2014, 5, 1, 20, 1, 10),
#   'pledged': 225,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 225.0,
#   'usd_pledged_real': 225.0},
#  {'_id': 1675510469,
#   'name': 'LAN Center',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 10, 26, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2014, 9, 26, 8, 19, 38),
#   'pledged': 2,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 588787421,
#   'name': 'jfg76tukv u',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 12, 31, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2015, 11, 19, 16, 47, 3),
#   'pledged': 2,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 742934297,
#   'name': 'Shaft in Asia Featured Film',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 10, 13, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2015, 8, 14, 22, 56, 40),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 715019941,
#   'name': 'P.U.R.E. Gamers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 10, 4, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2015, 8, 6, 22, 22),
#   'pledged': 25,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 818541249,
#   'name': 'The Hawaiian Girl Art Studio (Canceled)',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 3, 24, 0, 0),
#   'goal': 1100000,
#   'launched': datetime.datetime(2016, 1, 26, 5, 48, 5),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1312071514,
#   'name': 'The Rock Bar - Mobile Bar/Event Platform',
#   'category': 'Events',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 5, 24, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2015, 4, 9, 1, 28, 16),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 206228383,
#   'name': 'The Wager',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 4, 12, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2015, 2, 11, 20, 2),
#   'pledged': 10,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 466162671,
#   'name': 'xFaire: A TV Device. Watch Any Content, Anytime & Anywhere',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 7, 21, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2016, 6, 6, 20, 36, 49),
#   'pledged': 3523,
#   'state': 'canceled',
#   'backers': 29,
#   'country': 'US',
#   'usd pledged': 3227.0,
#   'usd_pledged_real': 3523.0},
#  {'_id': 1051776765,
#   'name': 'Independent Broadcasting Company',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 5, 31, 0, 0),
#   'goal': 700000,
#   'launched': datetime.datetime(2017, 4, 1, 2, 34, 51),
#   'pledged': 56,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': 595664945,
#   'name': 'Forbidden Woods (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 8, 18, 0, 0),
#   'goal': 2300000,
#   'launched': datetime.datetime(2012, 7, 19, 21, 12, 51),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1348230166,
#   'name': "Max and Rex's Adventure",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 5, 12, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2012, 3, 28, 4, 6, 56),
#   'pledged': 4286,
#   'state': 'failed',
#   'backers': 21,
#   'country': 'US',
#   'usd pledged': 4286.0,
#   'usd_pledged_real': 4286.0},
#  {'_id': 788197692,
#   'name': 'The Guilt Free Life',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 8, 27, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2014, 6, 28, 22, 5, 3),
#   'pledged': 20,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': 1254965074,
#   'name': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca',
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 4, 19, 0, 0),
#   'goal': 780000,
#   'launched': datetime.datetime(2015, 2, 18, 17, 23, 50),
#   'pledged': 267,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 267.0,
#   'usd_pledged_real': 267.0},
#  {'_id': 178418310,
#   'name': 'Puzzle Camp',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 6, 18, 0, 0),
#   'goal': 750000,
#   'launched': datetime.datetime(2014, 5, 19, 3, 56, 46),
#   'pledged': 35,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 1473597203,
#   'name': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2018, 1, 11, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2017, 12, 12, 18, 46, 26),
#   'pledged': 5651,
#   'state': 'live',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1248.0,
#   'usd_pledged_real': 5651.0},
#  {'_id': 715203303,
#   'name': "THE YING YANG MURDER MYSTERY'S (Canceled)",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 12, 31, 0, 0),
#   'goal': 900000,
#   'launched': datetime.datetime(2014, 12, 1, 23, 50, 57),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 374403417,
#   'name': 'Montgomery Al Concert 5FDP and VOLBEAT',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 7, 24, 0, 0),
#   'goal': 1040000,
#   'launched': datetime.datetime(2014, 6, 24, 2, 58, 50),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1935538858,
#   'name': 'Wall Scaler',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 4, 17, 0, 0),
#   'goal': 1000000,
#   'launched': datetime.datetime(2017, 3, 3, 21, 30, 39),
#   'pledged': 1,
#   'state': 'suspended',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1926637288,
#   'name': 'Historic B&B with an in-house French Bakery in Memphis, TN',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 7, 23, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2016, 6, 23, 1, 13, 20),
#   'pledged': 10100,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 10100.0,
#   'usd_pledged_real': 10100.0},
#  {'_id': 781443672,
#   'name': 'Eternal Fate',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 9, 1, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2012, 8, 2, 7, 36, 8),
#   'pledged': 12914,
#   'state': 'failed',
#   'backers': 234,
#   'country': 'US',
#   'usd pledged': 12914.0,
#   'usd_pledged_real': 12914.0},
#  {'_id': 1715597415,
#   'name': 'Angelz Landing the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 2, 17, 0, 0),
#   'goal': 1200000,
#   'launched': datetime.datetime(2014, 1, 13, 19, 8, 9),
#   'pledged': 356,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 356.0,
#   'usd_pledged_real': 356.0},
#  {'_id': 779336498,
#   'name': 'Morrison Land',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 7, 27, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2014, 5, 28, 19, 42, 35),
#   'pledged': 10,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1934580784,
#   'name': 'Triple Espresso Goes to The Big Apple',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 3, 16, 0, 0),
#   'goal': 300000,
#   'launched': datetime.datetime(2013, 2, 9, 21, 1, 57),
#   'pledged': 27581,
#   'state': 'failed',
#   'backers': 116,
#   'country': 'US',
#   'usd pledged': 27581.0,
#   'usd_pledged_real': 27581.0},
#  {'_id': 107644423,
#   'name': 'Meetupgolf - Everything Golf, Everything Social',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 9, 21, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2016, 8, 22, 18, 44, 37),
#   'pledged': 360,
#   'state': 'canceled',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 360.0},
#  {'_id': 1081925218,
#   'name': 'GunDetect - alerts you when it sees a gun',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 8, 20, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2015, 7, 15, 1, 3, 4),
#   'pledged': 43718,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 43718.0,
#   'usd_pledged_real': 43718.0},
#  {'_id': 1596314651,
#   'name': 'Take And Seek the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 9, 16, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2013, 8, 16, 4, 59, 36),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1834526569,
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 2, 15, 0, 0),
#   'goal': 600000,
#   'launched': datetime.datetime(2014, 1, 14, 19, 3, 30),
#   'pledged': 660126,
#   'state': 'successful',
#   'backers': 15824,
#   'country': 'US',
#   'usd pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': 2007557271,
#   'name': 'Harishwar Center for Arts, Spirituality & Sustainability',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 2, 3, 0, 0),
#   'goal': 1800000,
#   'launched': datetime.datetime(2016, 1, 4, 20, 26, 57),
#   'pledged': 614,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 614.0,
#   'usd_pledged_real': 614.0},
#  {'_id': 695668947,
#   'name': "The Cancer Patient's Film Project",
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 8, 17, 0, 0),
#   'goal': 1500000,
#   'launched': datetime.datetime(2013, 7, 12, 2, 38, 19),
#   'pledged': 275,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 275.0,
#   'usd_pledged_real': 275.0},
#  {'_id': 832080779,
#   'name': "Small Change: Kids' Financial Life Skills",
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 8, 11, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2014, 7, 17, 15, 54, 12),
#   'pledged': 3536,
#   'state': 'failed',
#   'backers': 39,
#   'country': 'US',
#   'usd pledged': 3536.0,
#   'usd_pledged_real': 3536.0},
#  {'_id': 1656648684,
#   'name': 'Save the Williamsburg',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 10, 27, 0, 0),
#   'goal': 40000000,
#   'launched': datetime.datetime(2015, 9, 27, 15, 8, 5),
#   'pledged': 21700,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'US',
#   'usd pledged': 21700.0,
#   'usd_pledged_real': 21700.0},
#  {'_id': 256448010,
#   'name': 'Nephilim, Nazis and the New World Order',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 7, 12, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2015, 5, 13, 3, 45, 32),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 978588144,
#   'name': 'War At Home',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 11, 28, 0, 0),
#   'goal': 340000,
#   'launched': datetime.datetime(2015, 10, 29, 16, 0, 52),
#   'pledged': 19328,
#   'state': 'failed',
#   'backers': 273,
#   'country': 'US',
#   'usd pledged': 19328.0,
#   'usd_pledged_real': 19328.0},
#  {'_id': 208391519,
#   'name': 'North East',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 7, 23, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2017, 5, 24, 0, 17, 26),
#   'pledged': 2,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 1789241689,
#   'name': 'The Great Pyramid, Project USA',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 8, 1, 0, 0),
#   'goal': 300000,
#   'launched': datetime.datetime(2014, 6, 2, 15, 53, 58),
#   'pledged': 35,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 2126842880,
#   'name': 'Time travel app',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 10, 9, 0, 0),
#   'goal': 375000,
#   'launched': datetime.datetime(2017, 9, 12, 21, 6, 34),
#   'pledged': 135,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 135.0},
#  {'_id': 1046230768,
#   'name': 'Honolulu Haze (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 7, 7, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2013, 5, 8, 18, 0, 16),
#   'pledged': 70,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': 2135350794,
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 1, 18, 0, 0),
#   'goal': 600000,
#   'launched': datetime.datetime(2014, 11, 19, 20, 20, 55),
#   'pledged': 200,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 381953552,
# ...
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 11, 17, 0, 0),
#   'goal': 400000,
#   'launched': datetime.datetime(2014, 10, 16, 3, 33, 7),
#   'pledged': 10772,
#   'state': 'failed',
#   'backers': 82,
#   'country': 'US',
#   'usd pledged': 10772.0,
#   'usd_pledged_real': 10772.0},
#  {'_id': 1544030819,
#   'name': "PrivacyAtlas - It's Your Life - Make Sure It's Protected!",
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 7, 8, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2014, 6, 23, 18, 44),
#   'pledged': 56,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': 1643578684,
#   'name': 'Thumper (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 6, 28, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2013, 5, 29, 14, 58, 20),
#   'pledged': 6961,
#   'state': 'canceled',
#   'backers': 35,
#   'country': 'US',
#   'usd pledged': 6961.0,
#   'usd_pledged_real': 6961.0},
#  {'_id': 422405466,
#   'name': 'ME+ "Electricfying Our World"',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 10, 20, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2014, 9, 10, 23, 31, 44),
#   'pledged': 151,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 151.0,
#   'usd_pledged_real': 151.0},
#  {'_id': 1300624545,
#   'name': 'www.GuysDoLunch.com',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 3, 13, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2015, 2, 11, 20, 55, 11),
#   'pledged': 25,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 1369023580,
#   'name': 'PetWashSPA: The first home SPA system for your pets.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 4, 12, 0, 0),
#   'goal': 220000,
#   'launched': datetime.datetime(2015, 2, 26, 2, 53, 7),
#   'pledged': 1198,
#   'state': 'canceled',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1198.0,
#   'usd_pledged_real': 1198.0},
#  {'_id': 222456629,
#   'name': 'imealhost.com',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 11, 19, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2015, 10, 21, 1, 8, 6),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 553403140,
#   'name': 'FOCUS ON THE OCEAN',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 8, 26, 0, 0),
#   'goal': 350000,
#   'launched': datetime.datetime(2012, 7, 27, 2, 22, 39),
#   'pledged': 1226,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 1226.0,
#   'usd_pledged_real': 1226.0},
#  {'_id': 1141827345,
#   'name': 'Ground Branch',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 7, 7, 0, 0),
#   'goal': 425000,
#   'launched': datetime.datetime(2012, 6, 2, 0, 56, 28),
#   'pledged': 111111,
#   'state': 'failed',
#   'backers': 1897,
#   'country': 'US',
#   'usd pledged': 111111.54,
#   'usd_pledged_real': 111111.54},
#  {'_id': 590993419,
#   'name': 'Leviathans Online: Monsters In The Sky (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 1, 17, 0, 0),
#   'goal': 300000,
#   'launched': datetime.datetime(2012, 12, 3, 17, 23, 7),
#   'pledged': 10556,
#   'state': 'canceled',
#   'backers': 213,
#   'country': 'US',
#   'usd pledged': 10556.03,
#   'usd_pledged_real': 10556.03},
#  {'_id': 133310028,
#   'name': "William Malone's THALLIUM'S BOX",
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 6, 1, 0, 0),
#   'goal': 350000,
#   'launched': datetime.datetime(2015, 5, 2, 23, 13, 40),
#   'pledged': 19410,
#   'state': 'failed',
#   'backers': 71,
#   'country': 'US',
#   'usd pledged': 19410.0,
#   'usd_pledged_real': 19410.0},
#  {'_id': 962949560,
#   'name': '"PG" Reanimated Cartoons Tha Movie',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 4, 11, 0, 0),
#   'goal': 100000000,
#   'launched': datetime.datetime(2015, 2, 10, 23, 49, 30),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 870909178,
#   'name': 'SportsBucketList.net',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 3, 13, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2015, 2, 11, 20, 51, 31),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1139392193,
#   'name': 'Bridging the Minooka area to "Back in the Day"',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 10, 30, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2014, 9, 15, 19, 19, 56),
#   'pledged': 1,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 473043717,
#   'name': 'DMG Recording Studio',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 2, 26, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2015, 1, 27, 2, 28, 55),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1221279169,
#   'name': 'ProTap: Draft Beer, Wine, and Cold Beverage Dispenser',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 4, 20, 0, 0),
#   'goal': 350000,
#   'launched': datetime.datetime(2017, 3, 21, 19, 25, 56),
#   'pledged': 7188,
#   'state': 'failed',
#   'backers': 21,
#   'country': 'US',
#   'usd pledged': 3565.0,
#   'usd_pledged_real': 7188.0},
#  {'_id': 438065651,
#   'name': 'The Bobcat Exterior Rodent Bait Station',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 4, 29, 0, 0),
#   'goal': 225000,
#   'launched': datetime.datetime(2015, 3, 30, 19, 43, 4),
#   'pledged': 179,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 179.0,
#   'usd_pledged_real': 179.0},
#  {'_id': 1714819094,
#   'name': 'Edesia: Fresh, homemade and delicious Italian food!',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 8, 20, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2014, 7, 21, 17, 45, 3),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 518050281,
#   'name': 'Your Way Game Board',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 9, 4, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2014, 8, 5, 23, 13),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1361206718,
#   'name': 'Endorsit: Reviewed by You... Endorsed by the Community',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 4, 27, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2016, 2, 27, 17, 20, 57),
#   'pledged': 137,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 137.0,
#   'usd_pledged_real': 137.0},
#  {'_id': 577847537,
#   'name': 'Bobby Rush: Live at the Great Wall of China',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 4, 15, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2013, 3, 14, 19, 25, 26),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 535694516,
#   'name': 'A Gangster Movie called,  GET LOUIE',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 8, 6, 0, 0),
#   'goal': 2000000,
#   'launched': datetime.datetime(2015, 6, 7, 17, 22, 55),
#   'pledged': 20,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': 1296255094,
#   'name': 'Stark Drive Electric Bike',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 12, 31, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2016, 11, 1, 11, 55, 45),
#   'pledged': 17854,
#   'state': 'canceled',
#   'backers': 22,
#   'country': 'US',
#   'usd pledged': 2622.0,
#   'usd_pledged_real': 17854.0},
#  {'_id': 1823366426,
#   'name': 'Atheism is Winning! (Canceled)',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 11, 29, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2014, 9, 30, 20, 5, 9),
#   'pledged': 0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1039730493,
#   'name': 'Metroryde technology for riders and independent operators',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 12, 21, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2016, 11, 8, 5, 58, 12),
#   'pledged': 155,
#   'state': 'canceled',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 155.0},
#  {'_id': 1631352976,
#   'name': 'GRANNY, The Movie (starring Jamie Kennedy) (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 10, 7, 0, 0),
#   'goal': 500000,
#   'launched': datetime.datetime(2013, 9, 7, 1, 0, 19),
#   'pledged': 601,
#   'state': 'canceled',
#   'backers': 20,
#   'country': 'US',
#   'usd pledged': 601.0,
#   'usd_pledged_real': 601.0},
#  {'_id': 1881943558,
#   'name': 'Wining and Dining on the Yacht',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 9, 22, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2015, 8, 23, 22, 2, 49),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 2045524340,
#   'name': 'Saving Trayvon',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 5, 11, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2012, 4, 11, 4, 58, 14),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 557482111,
#   'name': 'Trendy - Style Simplified',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2016, 9, 23, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2016, 8, 24, 18, 19, 9),
#   'pledged': 15,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 15.0,
#   'usd_pledged_real': 15.0},
#  {'_id': 1390150792,
#   'name': 'The Citizen Body Camera with Tamper-proof Online Backup',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 6, 26, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2015, 4, 27, 10, 54, 6),
#   'pledged': 167,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 167.0,
#   'usd_pledged_real': 167.0},
#  {'_id': 768907657,
#   'name': 'The Good Guys (Blood over Everything)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 8, 25, 0, 0),
#   'goal': 250000,
#   'launched': datetime.datetime(2013, 6, 26, 0, 0, 5),
#   'pledged': 202,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 202.06,
#   'usd_pledged_real': 202.06},
#  {'_id': 1242311139,
#   'name': 'BAD PLANET',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2012, 8, 16, 0, 0),
#   'goal': 575000,
#   'launched': datetime.datetime(2012, 7, 12, 15, 2, 21),
#   'pledged': 45415,
#   'state': 'failed',
#   'backers': 638,
#   'country': 'US',
#   'usd pledged': 45415.91,
#   'usd_pledged_real': 45415.91},
#  {'_id': 715537620,
#   'name': 'Winthrop and Chester (Canceled)',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2013, 6, 29, 0, 0),
#   'goal': 200000,
#   'launched': datetime.datetime(2013, 5, 30, 22, 43, 1),
#   'pledged': 2930,
#   'state': 'canceled',
#   'backers': 62,
#   'country': 'US',
#   'usd pledged': 2930.0,
#   'usd_pledged_real': 2930.0},
#  {'_id': 1863870779,
#   'name': 'BodyCopter',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 12, 10, 0, 0),
#   'goal': 2000000,
#   'launched': datetime.datetime(2017, 11, 10, 0, 56, 36),
#   'pledged': 240,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 240.0},
#  {'_id': 1070802237,
#   'name': 'XCenter College Of Art, Music & Design',
#   'category': 'Civic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2017, 1, 30, 0, 0),
#   'goal': 10000000,
#   'launched': datetime.datetime(2016, 12, 1, 3, 27, 13),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 964395491,
#   'name': 'Rainbow Reef : a sit-com starring Ed Asner & Danilo DiJulio',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 4, 18, 0, 0),
#   'goal': 400000,
#   'launched': datetime.datetime(2014, 3, 17, 23, 36, 45),
#   'pledged': 565,
#   'state': 'canceled',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 565.0,
#   'usd_pledged_real': 565.0},
#  {'_id': 1528846653,
#   'name': 'Hotbox Hooka',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 8, 3, 0, 0),
#   'goal': 450000,
#   'launched': datetime.datetime(2015, 7, 4, 21, 26, 50),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 838492504,
#   'name': 'Save Black Earth Meats',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 12, 4, 0, 0),
#   'goal': 225000,
#   'launched': datetime.datetime(2014, 10, 20, 19, 4, 6),
#   'pledged': 91116,
#   'state': 'failed',
#   'backers': 991,
#   'country': 'US',
#   'usd pledged': 91116.0,
#   'usd_pledged_real': 91116.0},
#  {'_id': 1535995528,
#   'name': 'Spokios.tv',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2015, 3, 16, 0, 0),
#   'goal': 1500000,
#   'launched': datetime.datetime(2015, 1, 16, 23, 25, 39),
#   'pledged': 0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1219018810,
#   'name': 'Apparatus for harnessing solar energy Patent US 8,770,186 B2',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': datetime.datetime(2014, 12, 31, 0, 0),
#   'goal': 20000000,
#   'launched': datetime.datetime(2014, 11, 6, 13, 51, 26),
#   'pledged': 4,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 4.0,
#   'usd_pledged_real': 4.0},
#  ...]

# %% [markdown]
# ## Question 6

# %%
collection.createIndex({"name":"text"})
name_sport = collection.find( { "$text": { "$search": "sport" } } )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-11b34de291ee> in <module>
# ----> 1 collection.createIndex({"name":"text"})
#       2 name_sport = collection.find( { "$text": { "$search": "sport" } } )
#
# ~/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/pymongo/collection.py in __call__(self, *args, **kwargs)
#    3443                             "exists." %
#    3444                             self.__name)
# -> 3445         raise TypeError("'Collection' object is not callable. If you meant to "
#    3446                         "call the '%s' method on a 'Collection' object it is "
#    3447                         "failing because no such method exists." %
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'createIndex' method on a 'Collection' object it is failing because no such method exists.
